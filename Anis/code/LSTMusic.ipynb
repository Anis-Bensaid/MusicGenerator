# %% [markdown]
# # LSTMusic with key and metro

# %%
import pandas as pd
import re
from music21 import *
import numpy as np

import time
import math
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# torch.cuda.is_available() checks and returns a Boolean True if a GPU is available, else it'll return False
is_cuda = torch.cuda.is_available()

# If we have a GPU available, we'll set our device to GPU. We'll use this device variable later in our code.
if is_cuda:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
# INPUT_PATH = "/content/drive/My Drive/Colab Notebooks/MusicGenerator/data/jiggs.txt"
# OUTPUT_PATH = "/content/drive/My Drive/Colab Notebooks/MusicGenerator/models"
INPUT_PATH = "../data/jiggs.txt"
OUTPUT_PATH = "../models/"

# %% [markdown]
# ## Data Formatting

# %%
class Repertoir():
    def __init__(self, path):
        self.path = path
        f = open(path, "r")
        self.string = f.read()
        self.handler = abcFormat.ABCHandler()
        self.handler.process(self.string)
        self.songs_handlers = self.handler.splitByReferenceNumber()
        self.songs = {}
        self.__process()
    
    def __str__(self):
        return self.string
    
    
    def __process(self):
        for ref_number, handler in self.songs_handlers.items():
            self.songs[ref_number] = Song(handler)
            
    def get_part_vocab(self):
        tokens = []
        for ref_number, song in self.songs.items():
            tokens+= song.part
        tokens = list(set(tokens))            
        return sorted(tokens)
    
    def get_metadata_vocab(self, key):
        tokens = []
        for ref_number, song in self.songs.items():
            tokens+= [song.metadata[key]]
        tokens = list(set(tokens))            
        return sorted(tokens)

# %%
class Song():
    def __init__(self, handler):
        self.handler = handler
        self.metadata = {
            'X':1,
            'T':'Unknown',
            'S':'Unknown',
            'M':'none',
            'L':'',
            'Q':'',
            'K':''
        }
        self.part = []
        self.__process()
        
    def __process(self):
        for token in self.handler.tokens:
            meta_data_ended=False
            if isinstance(token, abcFormat.ABCMetadata):
                if token.tag in self.metadata.keys():
                    if self.metadata[token.tag]=='' or not meta_data_ended:
                        self.metadata[token.tag] = token.data
                else:
                    self.metadata[token.tag] = token.data
            elif isinstance(token, abcFormat.ABCNote ) or isinstance(token, abcFormat.ABCBar):
                meta_data_ended = True
                self.part.append(token.src)
    
    def __str__(self):
        return self.to_abc()
    
    def to_abc(self):
        output = ''
        for key, value in self.metadata.items():
            output+= key+':'+value+"\n"
        for note in self.part:
            output+=note
        return output

# %%
def generate_char_idx_mappings(vocab):
    char2idx = {u:i for i, u in enumerate(vocab)}
    idx2char = np.array(vocab)
    return char2idx, idx2char

# %%
def get_input_tensors(part, k, m, part_char2idx, k_char2idx, m_char2idx):
    part_tensor = torch.tensor([part_char2idx[note] for note in part[0:-1]], dtype=torch.long)
    k_tensor = torch.tensor([k_char2idx[k] for note in part[0:-1]], dtype=torch.long)
    m_tensor = torch.tensor([m_char2idx[m] for note in part[0:-1]], dtype=torch.long)
    return part_tensor, k_tensor, m_tensor,

def get_target_tensor(part, part_char2idx):
    target_tensor = torch.tensor([part_char2idx[note] for note in part[1:]], dtype=torch.long)
    return target_tensor

# %%
rep = Repertoir(INPUT_PATH)

# %%
part_vocab = rep.get_part_vocab()
m_vocab = rep.get_metadata_vocab('M')
k_vocab = rep.get_metadata_vocab('K')

# %%
part_char2idx, part_idx2char = generate_char_idx_mappings(part_vocab)
k_char2idx, k_idx2char = generate_char_idx_mappings(k_vocab)
m_char2idx, m_idx2char = generate_char_idx_mappings(m_vocab)

# %% [markdown]
# ## LSTMusic

# %%
class LSTMusic(nn.Module):
    def __init__(self, 
                 part_vocab_size, 
                 k_vocab_size, 
                 m_vocab_size,
                 part_embedding_dim = 512, 
                 k_embedding_dim = 8, 
                 m_embedding_dim = 8, 
                 lstm_dim = 256,
                 drop_prob = 0.2,
                 num_lstm_layers = 3,
                 bidirectional = False
):
        super(LSTMusic, self).__init__()
        self.lstm_dim = lstm_dim
        self.num_lstm_layers = num_lstm_layers
        
        self.part_embeddings = nn.Embedding(part_vocab_size, part_embedding_dim)
        self.k_embeddings = nn.Embedding(k_vocab_size, k_embedding_dim)
        self.m_embeddings = nn.Embedding(m_vocab_size, m_embedding_dim)

        self.lstm = nn.LSTM(input_size = m_embedding_dim + k_embedding_dim + part_embedding_dim, 
                            hidden_size = lstm_dim,
                            num_layers = num_lstm_layers,
                            dropout = drop_prob,
                            bidirectional = bidirectional 
                           )

        self.dense = nn.Linear(lstm_dim, part_vocab_size)

    def forward(self, part, k, m, hidden):
        part_embeds = self.part_embeddings(part)
        k_embeds = self.k_embeddings(k)
        m_embeds = self.m_embeddings(m)
        combined = torch.cat((m_embeds, k_embeds, part_embeds), 1)
        lstm_out, hidden = self.lstm(combined.view(len(part), 1, -1), hidden)
        output = self.dense(lstm_out.view(len(part), -1))
        return output, hidden
    
    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        hidden = (weight.new(self.num_lstm_layers, batch_size, self.lstm_dim).zero_().to(device),
                  weight.new(self.num_lstm_layers, batch_size, self.lstm_dim).zero_().to(device))
        return hidden

# %%
def generate(model, start, k, m, length, top_k=2):
    model = model.eval()
    pred_notes = []

    with torch.no_grad():  # no need to track history in sampling
        hidden = model.init_hidden(1)
        start_tensor, k_tensor, m_tensor = get_input_tensors(start + [' '], k, m, part_char2idx, k_char2idx, m_char2idx)
        start_tensor, k_tensor, m_tensor = start_tensor.to(device), k_tensor.to(device), m_tensor.to(device)
        output, hidden = model(start_tensor, k_tensor, m_tensor, hidden)
        _, top_idx = torch.topk(output[-1], k=top_k)
        choice = np.random.choice(top_idx.tolist())
        pred_notes.append(part_idx2char[choice])
        note_tensor =  torch.tensor(choice, dtype=torch.long).unsqueeze(0)
        k_tensor = k_tensor[0].unsqueeze(0)
        m_tensor = m_tensor[0].unsqueeze(0)
        for _ in range(length):
            note_tensor, k_tensor, m_tensor = note_tensor.to(device), k_tensor.to(device), m_tensor.to(device)
            output, hidden = model(note_tensor, k_tensor, m_tensor, hidden)
            _, top_idx = torch.topk(output[-1], k=top_k)
            choice = np.random.choice(top_idx.tolist())
            pred_notes.append(part_idx2char[choice])
            note_tensor =  torch.tensor(choice, dtype=torch.long).unsqueeze(0)

    abc = "M:{}\nK:{}\n".format(m,k) + ''.join(start) + ''.join(pred_notes)
    print(abc)
    return abc, pred_notes

# %%
def timeSince(since):
    now = time.time()
    s = now - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %%
part_vocab_size = len(part_vocab)
k_vocab_size = len(k_vocab)
m_vocab_size = len(m_vocab)

nb_epoch = 10000
lr = 0.001
max_norm = 5

start_part = rep.songs[15].part[0:5]
start_k = rep.songs[15].metadata['K']
start_m = rep.songs[15].metadata['M']
length = 100

# %%
model = LSTMusic(part_vocab_size, k_vocab_size, m_vocab_size)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

start = time.time()
epoch = 0
for epoch in range(1,nb_epoch+1):
    print('\n========= Epoch {} out of {} ({} %) =========\n'.format(epoch, nb_epoch, (epoch)/nb_epoch*100))
    nb_iters = len(rep.songs)
    iteration = 0
    print_every = nb_iters//10
    hidden = model.init_hidden(1)
    songs_idxs = list(rep.songs.keys())
    
    for iteration in range(1, len(songs_idxs)+1):
        song_idx = np.random.choice(songs_idxs)
        song = rep.songs[song_idx]
        
        model = model.train()

        model.zero_grad()
        
        part, k, m  = get_input_tensors(song.part, song.metadata['K'], song.metadata['M'], part_char2idx, k_char2idx, m_char2idx)
        target = get_target_tensor(song.part, part_char2idx)
        
        part, k, m, target = part.to(device), k.to(device), m.to(device), target.to(device)
        
        output, hidden = model(part, k, m, hidden)
        
        hidden = (hidden[0].detach(), hidden[1].detach())
        
        loss = criterion(output, target)
        loss.backward()

        nn.utils.clip_grad_norm_(model.parameters(), max_norm)
        
        optimizer.step()
        
        if iteration % print_every == 0:
            model.eval()
            num_correct = 0
            pred = torch.argmax(output, dim=1)
            correct_tensor = pred.eq(target)
            correct = np.squeeze(correct_tensor.cpu().numpy())
            acc = np.sum(correct)/len(part)*100
            model.train()
            print('%s (%d %d%%) || loss: %.4f || accuracy: %.3f%% || Song ID: %d' % (timeSince(start), iteration, iteration / nb_iters * 100, loss.item(), acc, song_idx))
    print('\nGenerating example :\n')
    abc, op_notes = generate(model, start_part, start_k, start_m, length)    
    torch.save(model.state_dict(),os.path.join(OUTPUT_PATH,'model-{}.pth'.format(epoch)))
# Out:
# ========= Epoch 1 out of 10000 (0.01 %) =========
#
# 0m 3s (34 10%) || loss: 3.5811 || accuracy: 15.534% || Song ID: 114
# 0m 6s (68 20%) || loss: 4.0778 || accuracy: 17.204% || Song ID: 135
# 0m 10s (102 30%) || loss: 4.1833 || accuracy: 16.438% || Song ID: 75
# 0m 14s (136 40%) || loss: 4.8430 || accuracy: 12.261% || Song ID: 223
# 0m 18s (170 50%) || loss: 4.2700 || accuracy: 22.727% || Song ID: 304
# 0m 21s (204 60%) || loss: 4.5954 || accuracy: 15.625% || Song ID: 123
# 0m 25s (238 70%) || loss: 3.5743 || accuracy: 20.202% || Song ID: 166
# 0m 29s (272 80%) || loss: 3.4665 || accuracy: 14.151% || Song ID: 317
# 0m 32s (306 90%) || loss: 3.5938 || accuracy: 22.936% || Song ID: 177
# 0m 36s (340 100%) || loss: 3.6060 || accuracy: 21.053% || Song ID: 303
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|AeAG|BeGGGG|AGAA|AeAG|BGGGG|BeGA|AeGA|BeAG|AeGA|AeGGG|AeAAGG|BGAA|BGAA|AeGGG|BGGA|BGGG|AGGGGG|BeAGGG|
#
# ========= Epoch 2 out of 10000 (0.02 %) =========
#
# 0m 40s (34 10%) || loss: 3.4803 || accuracy: 17.431% || Song ID: 234
# 0m 44s (68 20%) || loss: 3.4620 || accuracy: 17.910% || Song ID: 201
# 0m 47s (102 30%) || loss: 3.6414 || accuracy: 26.829% || Song ID: 296
# 0m 51s (136 40%) || loss: 3.3761 || accuracy: 24.419% || Song ID: 227
# 0m 55s (170 50%) || loss: 2.9769 || accuracy: 23.923% || Song ID: 169
# 0m 58s (204 60%) || loss: 4.4245 || accuracy: 15.888% || Song ID: 19
# 1m 2s (238 70%) || loss: 3.7908 || accuracy: 19.792% || Song ID: 123
# 1m 5s (272 80%) || loss: 3.2474 || accuracy: 18.182% || Song ID: 101
# 1m 9s (306 90%) || loss: 2.7782 || accuracy: 28.889% || Song ID: 301
# 1m 12s (340 100%) || loss: 3.3595 || accuracy: 20.455% || Song ID: 155
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"dAAdAAA|"D"feefff|"D"ffefeeg|"G"dBAdBA|"D"feffee|"G"ddAAAcAA|"D"fefeff|"G"dBcdd|"G"dABdBc|"D"fffeeeg|"G"dddeefg|"D"feefefg|"D"ffffeeg|:|"D"ff
#
# ========= Epoch 3 out of 10000 (0.03 %) =========
#
# 1m 16s (34 10%) || loss: 3.0951 || accuracy: 27.985% || Song ID: 201
# 1m 20s (68 20%) || loss: 3.4355 || accuracy: 23.448% || Song ID: 27
# 1m 24s (102 30%) || loss: 3.1439 || accuracy: 29.448% || Song ID: 7
# 1m 27s (136 40%) || loss: 2.5682 || accuracy: 30.108% || Song ID: 135
# 1m 31s (170 50%) || loss: 2.5818 || accuracy: 27.350% || Song ID: 30
# 1m 35s (204 60%) || loss: 3.2622 || accuracy: 20.000% || Song ID: 71
# 1m 38s (238 70%) || loss: 3.0029 || accuracy: 21.769% || Song ID: 117
# 1m 42s (272 80%) || loss: 2.5182 || accuracy: 30.769% || Song ID: 30
# 1m 45s (306 90%) || loss: 2.1999 || accuracy: 39.048% || Song ID: 267
# 1m 49s (340 100%) || loss: 2.6374 || accuracy: 27.835% || Song ID: 257
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"D"dee"A7"eddedc|"G"Bcdeff|"D"affagg|"D"agfgff|"D"feeedd|"G"Bcdedc|"D"ddcAcc|"G"Bcdeffggfed|"D"dfggfgg|"D"agfgecA|"D"dedddc|"G"BccAcd|"D"ddd"A7"edcA
#
# ========= Epoch 4 out of 10000 (0.04 %) =========
#
# 1m 53s (34 10%) || loss: 2.3102 || accuracy: 40.000% || Song ID: 229
# 1m 56s (68 20%) || loss: 3.0575 || accuracy: 28.421% || Song ID: 20
# 2m 0s (102 30%) || loss: 2.6796 || accuracy: 31.132% || Song ID: 186
# 2m 4s (136 40%) || loss: 2.4827 || accuracy: 35.484% || Song ID: 134
# 2m 8s (170 50%) || loss: 2.2857 || accuracy: 38.462% || Song ID: 178
# 2m 12s (204 60%) || loss: 3.3461 || accuracy: 29.167% || Song ID: 84
# 2m 15s (238 70%) || loss: 2.7110 || accuracy: 31.481% || Song ID: 181
# 2m 19s (272 80%) || loss: 2.4254 || accuracy: 30.000% || Song ID: 301
# 2m 22s (306 90%) || loss: 2.3551 || accuracy: 38.261% || Song ID: 279
# 2m 26s (340 100%) || loss: 2.9153 || accuracy: 32.609% || Song ID: 297
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"G3A2:|c/2d/2d/2d/2d/2|"D"ffgagg|"D"fgfagf|"D"agggffgggggg|"D"aggagfg|"G"dddefeggg|"D"fggaggg|"D"fgggfe|"G"dBAGGGAA|"G"BGGGAAAA|"G"G3G2||[2"G"G3A2A|"G"BAGG2:|c/2
#
# ========= Epoch 5 out of 10000 (0.05 %) =========
#
# 2m 30s (34 10%) || loss: 2.7164 || accuracy: 32.927% || Song ID: 296
# 2m 34s (68 20%) || loss: 2.4256 || accuracy: 36.697% || Song ID: 177
# 2m 38s (102 30%) || loss: 2.7013 || accuracy: 27.211% || Song ID: 117
# 2m 42s (136 40%) || loss: 3.0944 || accuracy: 39.726% || Song ID: 26
# 2m 45s (170 50%) || loss: 3.2909 || accuracy: 27.368% || Song ID: 20
# 2m 48s (204 60%) || loss: 2.1980 || accuracy: 40.909% || Song ID: 262
# 2m 52s (238 70%) || loss: 2.9385 || accuracy: 28.235% || Song ID: 283
# 2m 56s (272 80%) || loss: 2.8514 || accuracy: 27.473% || Song ID: 216
# 2m 59s (306 90%) || loss: 3.5860 || accuracy: 30.000% || Song ID: 182
# 3m 3s (340 100%) || loss: 3.2424 || accuracy: 23.913% || Song ID: 339
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"G3G2:||:A|"G"G3A2:||:A|"G"G3G2:|[2"G"G2AA2B||"G"BGGG2B|"G"B2BA2G|"G"G3G2||DFGD|"G"G2BG2B|"G"G3A2|||:ED|:"G"G2GG2GAB|"G"BGAG2B|"G"B2BA2B|"G"BABcBA|"G"BGGG2:|[2"C"eedccc|"G"BGAA2B|"G"BGGG2:|
#
# ========= Epoch 6 out of 10000 (0.06 %) =========
#
# 3m 7s (34 10%) || loss: 2.0607 || accuracy: 41.935% || Song ID: 135
# 3m 11s (68 20%) || loss: 2.6657 || accuracy: 40.244% || Song ID: 172
# 3m 14s (102 30%) || loss: 2.9779 || accuracy: 32.632% || Song ID: 20
# 3m 18s (136 40%) || loss: 2.4149 || accuracy: 34.685% || Song ID: 8
# 3m 21s (170 50%) || loss: 2.4249 || accuracy: 44.138% || Song ID: 38
# 3m 25s (204 60%) || loss: 2.4449 || accuracy: 33.645% || Song ID: 45
# 3m 29s (238 70%) || loss: 2.6411 || accuracy: 40.336% || Song ID: 263
# 3m 32s (272 80%) || loss: 2.1670 || accuracy: 48.630% || Song ID: 235
# 3m 36s (306 90%) || loss: 2.2863 || accuracy: 42.391% || Song ID: 23
# 3m 39s (340 100%) || loss: 2.1529 || accuracy: 48.889% || Song ID: 301
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"Bcdcde|"G"dcBGGA|"G"G3G2||A|"G"BAGGFD:|[2"G"G3A2|||:B/2c/2|"G"Bcdefe|"D"d3d3:|[2"G"dBAGFD:||:A:||:A:||:A:||:BAAAA|"G"BcBA2A:|[2"G"Bcdded|"D"d3d2||A|"D"ddBABA:||:BAA|"G"Bc
#
# ========= Epoch 7 out of 10000 (0.06999999999999999 %) =========
#
# 3m 43s (34 10%) || loss: 2.1777 || accuracy: 38.994% || Song ID: 31
# 3m 47s (68 20%) || loss: 2.7278 || accuracy: 28.395% || Song ID: 336
# 3m 51s (102 30%) || loss: 2.9533 || accuracy: 34.896% || Song ID: 36
# 3m 54s (136 40%) || loss: 2.1082 || accuracy: 43.636% || Song ID: 170
# 3m 58s (170 50%) || loss: 2.1631 || accuracy: 53.846% || Song ID: 334
# 4m 2s (204 60%) || loss: 2.2542 || accuracy: 41.935% || Song ID: 271
# 4m 6s (238 70%) || loss: 2.4737 || accuracy: 40.816% || Song ID: 184
# 4m 9s (272 80%) || loss: 2.8606 || accuracy: 26.364% || Song ID: 71
# 4m 13s (306 90%) || loss: 3.0226 || accuracy: 31.148% || Song ID: 188
# 4m 17s (340 100%) || loss: 2.2803 || accuracy: 42.177% || Song ID: 208
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"D"dcBGGBc|"G"BGBdcBA|"G"G3A2:||:A|"D"ABcdcBA|"D"dcdefg|"C"edcdBG|"G"G3A2|||:B/2d/2|"G"g2gfefg|"D"fefaffg|"G"gfedBA|"G"G3G2:|[2"Em"e3d2:|[2"Em"e3e2e||"D"fedefe|"G"dBBGFA|"D"de
#
# ========= Epoch 8 out of 10000 (0.08 %) =========
#
# 4m 20s (34 10%) || loss: 2.9425 || accuracy: 35.165% || Song ID: 44
# 4m 24s (68 20%) || loss: 2.2829 || accuracy: 39.873% || Song ID: 121
# 4m 27s (102 30%) || loss: 2.3081 || accuracy: 47.260% || Song ID: 251
# 4m 31s (136 40%) || loss: 2.5900 || accuracy: 34.579% || Song ID: 43
# 4m 35s (170 50%) || loss: 2.9474 || accuracy: 38.043% || Song ID: 285
# 4m 38s (204 60%) || loss: 1.9943 || accuracy: 56.667% || Song ID: 265
# 4m 42s (238 70%) || loss: 2.4035 || accuracy: 41.176% || Song ID: 104
# 4m 46s (272 80%) || loss: 2.8886 || accuracy: 38.028% || Song ID: 270
# 4m 50s (306 90%) || loss: 2.8390 || accuracy: 38.068% || Song ID: 127
# 4m 53s (340 100%) || loss: 2.2305 || accuracy: 43.478% || Song ID: 247
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"D"dcBABc||"G"BABA2B|"A"A3A3|"G"d2BA2B|"G"BGGG2B||"G"BGGGFED|"G"G3A2:||:A|"G"BAGG2B||"G"B2GGAGFEEEEEEE|"G"G2GG2G|"D"FEFAABA|"G"G3G2|||:AA|"G"B2BA2G|"G"GAGGFG||"G"GABAFE:|[2
#
# ========= Epoch 9 out of 10000 (0.09 %) =========
#
# 4m 57s (34 10%) || loss: 2.4740 || accuracy: 36.275% || Song ID: 145
# 5m 1s (68 20%) || loss: 2.0478 || accuracy: 41.346% || Song ID: 105
# 5m 5s (102 30%) || loss: 2.7234 || accuracy: 34.375% || Song ID: 60
# 5m 8s (136 40%) || loss: 2.3206 || accuracy: 45.794% || Song ID: 314
# 5m 12s (170 50%) || loss: 2.6389 || accuracy: 38.068% || Song ID: 180
# 5m 16s (204 60%) || loss: 2.5010 || accuracy: 44.860% || Song ID: 19
# 5m 20s (238 70%) || loss: 2.7421 || accuracy: 36.496% || Song ID: 322
# 5m 23s (272 80%) || loss: 1.9316 || accuracy: 46.667% || Song ID: 67
# 5m 27s (306 90%) || loss: 2.2314 || accuracy: 38.095% || Song ID: 143
# 5m 31s (340 100%) || loss: 2.7710 || accuracy: 40.777% || Song ID: 149
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"G3G2:||:B/2c/2d/2g/2|"G"gagfedc|"D"dcdd2f|"G"gfe"G"dBG||"G"BAGG2||dBc|:ddB|"D"AGAA2B|"G"BAGGFD|"G"GBddBB||"D7"AGF"G"G2||"G"dBGGBd||"G"BABdBG|"G"GBB"D7"AGF|"G"G2GGAB|"G"BGBdcB
#
# ========= Epoch 10 out of 10000 (0.1 %) =========
#
# 5m 34s (34 10%) || loss: 2.2225 || accuracy: 50.515% || Song ID: 108
# 5m 38s (68 20%) || loss: 2.1527 || accuracy: 43.158% || Song ID: 96
# 5m 41s (102 30%) || loss: 1.9118 || accuracy: 50.538% || Song ID: 136
# 5m 45s (136 40%) || loss: 2.3289 || accuracy: 52.174% || Song ID: 133
# 5m 48s (170 50%) || loss: 2.6391 || accuracy: 41.379% || Song ID: 27
# 5m 52s (204 60%) || loss: 2.2347 || accuracy: 45.312% || Song ID: 60
# 5m 55s (238 70%) || loss: 2.4023 || accuracy: 45.263% || Song ID: 47
# 5m 59s (272 80%) || loss: 2.3663 || accuracy: 40.426% || Song ID: 335
# 6m 2s (306 90%) || loss: 2.8570 || accuracy: 33.333% || Song ID: 311
# 6m 5s (340 100%) || loss: 2.1951 || accuracy: 40.625% || Song ID: 326
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"BGGG2A|"D"deddBd:||:"G"BAFDFA:|[2"Am"A3A3:|[2"Am"A3A2|:d|"C"edcded|"C"edcdBG:|[2"Am"A3:|[2"Am"A3A2|:|:A|"D"dfefed|"A"cBAAFA|"D"def"A7"efg|"D"f2fd2fg|"D"fed"A"cBc:|[2"D"d3d2|||:AF|"G"G3G2||d
#
# ========= Epoch 11 out of 10000 (0.11 %) =========
#
# 6m 9s (34 10%) || loss: 1.9885 || accuracy: 55.245% || Song ID: 334
# 6m 13s (68 20%) || loss: 2.3029 || accuracy: 40.566% || Song ID: 164
# 6m 16s (102 30%) || loss: 1.7856 || accuracy: 52.174% || Song ID: 279
# 6m 20s (136 40%) || loss: 2.6511 || accuracy: 40.426% || Song ID: 224
# 6m 23s (170 50%) || loss: 1.7426 || accuracy: 57.547% || Song ID: 164
# 6m 27s (204 60%) || loss: 2.1636 || accuracy: 43.333% || Song ID: 202
# 6m 31s (238 70%) || loss: 2.2821 || accuracy: 48.485% || Song ID: 226
# 6m 34s (272 80%) || loss: 2.0628 || accuracy: 42.609% || Song ID: 1
# 6m 38s (306 90%) || loss: 3.1597 || accuracy: 35.862% || Song ID: 197
# 6m 42s (340 100%) || loss: 2.0190 || accuracy: 46.763% || Song ID: 213
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"BcBBcBA|"G"G3G2||d|"G"ded"D7"cBA:||:A||"G"BAGDED:|[2"Am"A3E2||d|"G"d2BB2B|"D"AGAGEF|"D"FEFGFD|"D"FAFD2:|d|"G"BcddBd|"C"edBGBd|"G"deddefgf|"Em"gfe"G"dcB||"A"A3A3||"G"dBGG2:|[2
#
# ========= Epoch 12 out of 10000 (0.12 %) =========
#
# 6m 45s (34 10%) || loss: 1.8323 || accuracy: 55.046% || Song ID: 177
# 6m 49s (68 20%) || loss: 2.6574 || accuracy: 39.568% || Song ID: 324
# 6m 53s (102 30%) || loss: 1.6435 || accuracy: 59.740% || Song ID: 323
# 6m 56s (136 40%) || loss: 2.3653 || accuracy: 53.488% || Song ID: 278
# 7m 0s (170 50%) || loss: 1.8731 || accuracy: 52.000% || Song ID: 118
# 7m 3s (204 60%) || loss: 2.0271 || accuracy: 47.748% || Song ID: 54
# 7m 7s (238 70%) || loss: 2.4583 || accuracy: 38.547% || Song ID: 128
# 7m 11s (272 80%) || loss: 2.6486 || accuracy: 38.487% || Song ID: 338
# 7m 15s (306 90%) || loss: 2.3007 || accuracy: 45.556% || Song ID: 333
# 7m 18s (340 100%) || loss: 2.3149 || accuracy: 53.425% || Song ID: 250
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"D"ABcABc:|[2"D"d3d2:||:A|"G"BGGG2:||:B/2d/2|"C"efeedB||"G"BABdBG|"D7"FGG"D7"FED:||:"D"ABdefe|"G"defagf|"Em"gdB"D"A2B||"D"AFAAFD:|[2"G"G3A2:||:B/2d/2|"C"efedefg|"C"efe"G"def|"G"gfg"D"fef
#
# ========= Epoch 13 out of 10000 (0.13 %) =========
#
# 7m 22s (34 10%) || loss: 2.3314 || accuracy: 42.857% || Song ID: 194
# 7m 25s (68 20%) || loss: 2.0725 || accuracy: 51.064% || Song ID: 9
# 7m 29s (102 30%) || loss: 1.6055 || accuracy: 61.682% || Song ID: 14
# 7m 33s (136 40%) || loss: 2.8488 || accuracy: 35.294% || Song ID: 254
# 7m 36s (170 50%) || loss: 1.8431 || accuracy: 53.425% || Song ID: 235
# 7m 40s (204 60%) || loss: 1.4371 || accuracy: 56.410% || Song ID: 30
# 7m 43s (238 70%) || loss: 1.7354 || accuracy: 56.757% || Song ID: 158
# 7m 47s (272 80%) || loss: 2.5514 || accuracy: 43.151% || Song ID: 26
# 7m 50s (306 90%) || loss: 1.6226 || accuracy: 55.046% || Song ID: 177
# 7m 55s (340 100%) || loss: 2.2438 || accuracy: 48.352% || Song ID: 216
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"D"FGAdBG:||:"D"AGAAGA|:"G"B2BBcd|"C"e2dcdc|"G"BAGG2:||:A|"G"BABBcdef|"G"gddgfe|"G"BGBBAG:|[2"Am"A3A2|:|:B/2c/2|"G"deddBG|"C"cBc"D"d2B|"Am"ABAAGF|"G"G3G3:||:"G"deddedBB|"Am"A3c2
#
# ========= Epoch 14 out of 10000 (0.13999999999999999 %) =========
#
# 7m 58s (34 10%) || loss: 1.3901 || accuracy: 57.273% || Song ID: 255
# 8m 2s (68 20%) || loss: 1.9983 || accuracy: 52.632% || Song ID: 151
# 8m 5s (102 30%) || loss: 2.0342 || accuracy: 47.436% || Song ID: 171
# 8m 9s (136 40%) || loss: 2.1398 || accuracy: 49.593% || Song ID: 295
# 8m 13s (170 50%) || loss: 2.1475 || accuracy: 52.874% || Song ID: 137
# 8m 16s (204 60%) || loss: 1.6922 || accuracy: 54.430% || Song ID: 121
# 8m 20s (238 70%) || loss: 1.5561 || accuracy: 60.839% || Song ID: 334
# 8m 24s (272 80%) || loss: 1.9540 || accuracy: 57.426% || Song ID: 34
# 8m 27s (306 90%) || loss: 1.5992 || accuracy: 50.909% || Song ID: 170
# 8m 30s (340 100%) || loss: 1.9410 || accuracy: 48.039% || Song ID: 68
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"D"FAFDFA|"G"BGG"D7"FED|"G"GFGBGG|"G"B2GG2F:|[2"G"G3D2:|[2"Am"A3A2|||:e/2e/2e/2e/2e/2c/2e/2A/2|"G"GBG"D7"FEF:|[2"Dm"FDDDEFE|"D"D3D3:|[2"A"EFEDFE:|[2"Dm"FEDD2:|[2"Dm"FEFDEF|"D"F2EDFG:|[2"Dm"FDCDEE|"G"GF
#
# ========= Epoch 15 out of 10000 (0.15 %) =========
#
# 8m 34s (34 10%) || loss: 2.5058 || accuracy: 34.188% || Song ID: 319
# 8m 37s (68 20%) || loss: 2.0606 || accuracy: 53.571% || Song ID: 93
# 8m 41s (102 30%) || loss: 1.3781 || accuracy: 60.909% || Song ID: 255
# 8m 45s (136 40%) || loss: 2.0497 || accuracy: 46.250% || Song ID: 189
# 8m 48s (170 50%) || loss: 2.0313 || accuracy: 48.889% || Song ID: 301
# 8m 52s (204 60%) || loss: 1.6589 || accuracy: 55.233% || Song ID: 227
# 8m 55s (238 70%) || loss: 1.7915 || accuracy: 53.086% || Song ID: 219
# 8m 59s (272 80%) || loss: 1.8838 || accuracy: 54.737% || Song ID: 151
# 9m 2s (306 90%) || loss: 2.0160 || accuracy: 52.000% || Song ID: 225
# 9m 6s (340 100%) || loss: 2.6415 || accuracy: 42.353% || Song ID: 254
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"BABdBG|"Am"AAce2c|"G"BAGG2B|:A|"G"BGED2B/2c/2|"G"BAGDGGFG2A|"G"BABdBG:|"G"BAGD2DB/2B/2|"G"GBddefa/2|"G"baaagaa/2|"G"gagfed:|"G"gagfef|"G"bge"D"agf|"G"gfg"D"afd:|[2"Em"e3"Em"gf
#
# ========= Epoch 16 out of 10000 (0.16 %) =========
#
# 9m 9s (34 10%) || loss: 2.1640 || accuracy: 44.974% || Song ID: 331
# 9m 13s (68 20%) || loss: 2.3393 || accuracy: 39.512% || Song ID: 81
# 9m 17s (102 30%) || loss: 1.8287 || accuracy: 47.887% || Song ID: 150
# 9m 20s (136 40%) || loss: 1.4458 || accuracy: 61.616% || Song ID: 226
# 9m 24s (170 50%) || loss: 1.7031 || accuracy: 49.451% || Song ID: 274
# 9m 27s (204 60%) || loss: 1.5662 || accuracy: 60.870% || Song ID: 124
# 9m 31s (238 70%) || loss: 1.6989 || accuracy: 55.056% || Song ID: 91
# 9m 34s (272 80%) || loss: 1.6051 || accuracy: 63.095% || Song ID: 332
# 9m 38s (306 90%) || loss: 1.6608 || accuracy: 53.271% || Song ID: 191
# 9m 41s (340 100%) || loss: 1.7069 || accuracy: 51.220% || Song ID: 49
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GG2F|"G"G3G2|||:B/2c/2d/2e/2f/2g/2|"G"g2dB2d|:"G"BdddBd|:dBBB|"G"G2GBAG:|"G"BGBBcB|:"D7"ABA"D7"FDF|:"G"GBcBcB|:"Em""Bm"BBdgfef|"G"g2gg2fe|"G"d2BBcB|"C"cBc"D"dBA|"G"BAGGFG|"G"GBBdBB|:
#
# ========= Epoch 17 out of 10000 (0.16999999999999998 %) =========
#
# 9m 45s (34 10%) || loss: 2.0831 || accuracy: 46.626% || Song ID: 120
# 9m 48s (68 20%) || loss: 2.0020 || accuracy: 48.031% || Song ID: 57
# 9m 51s (102 30%) || loss: 1.5958 || accuracy: 59.574% || Song ID: 300
# 9m 55s (136 40%) || loss: 1.9098 || accuracy: 52.299% || Song ID: 126
# 9m 59s (170 50%) || loss: 1.5590 || accuracy: 63.095% || Song ID: 332
# 10m 2s (204 60%) || loss: 2.6576 || accuracy: 33.333% || Song ID: 46
# 10m 6s (238 70%) || loss: 1.8677 || accuracy: 50.980% || Song ID: 220
# 10m 10s (272 80%) || loss: 1.3650 || accuracy: 59.028% || Song ID: 269
# 10m 13s (306 90%) || loss: 1.5826 || accuracy: 54.630% || Song ID: 310
# 10m 17s (340 100%) || loss: 1.6433 || accuracy: 62.637% || Song ID: 216
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GG2F|:"C"E2EDED|"G"G2GGFG|"G"dBdg2d|"G"deffef|"G"gagdBd|"G"gfgdefgf|"Em"gefgfg|"G"defgfg|"G"defgfg:|"C"efg"G"def|"G"gfe"G"dBG|"Am"Adc"D"d2:||:A:|[2"A"Acfgfe||"G"defg
#
# ========= Epoch 18 out of 10000 (0.18 %) =========
#
# 10m 21s (34 10%) || loss: 1.3065 || accuracy: 58.696% || Song ID: 16
# 10m 24s (68 20%) || loss: 1.6691 || accuracy: 51.961% || Song ID: 220
# 10m 28s (102 30%) || loss: 1.1154 || accuracy: 72.381% || Song ID: 67
# 10m 31s (136 40%) || loss: 2.1967 || accuracy: 48.276% || Song ID: 137
# 10m 35s (170 50%) || loss: 1.9985 || accuracy: 59.783% || Song ID: 168
# 10m 38s (204 60%) || loss: 1.7533 || accuracy: 57.143% || Song ID: 239
# 10m 42s (238 70%) || loss: 2.1520 || accuracy: 50.000% || Song ID: 254
# 10m 45s (272 80%) || loss: 1.7237 || accuracy: 57.432% || Song ID: 293
# 10m 49s (306 90%) || loss: 1.7823 || accuracy: 48.201% || Song ID: 213
# 10m 52s (340 100%) || loss: 1.9029 || accuracy: 54.386% || Song ID: 92
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"Em"BcGG2:||:A|:"G"BGEG2A|:"G"B2BB2A|"G"BGEG2A|"G"BABBcB|"C"cefg2ef|"G"g2dB2d|"C"e2ee2d||"C"efedcB|"D7"A3Ace|"G"dBGGBd:|[2"G"g2dBdd|"C"edeg2:||:d|"C"edeg2:||:ABc|:"G"Bddgfd|"G"d
#
# ========= Epoch 19 out of 10000 (0.19 %) =========
#
# 10m 56s (34 10%) || loss: 1.6673 || accuracy: 53.901% || Song ID: 103
# 11m 0s (68 20%) || loss: 1.4574 || accuracy: 63.478% || Song ID: 133
# 11m 3s (102 30%) || loss: 1.2741 || accuracy: 60.000% || Song ID: 55
# 11m 6s (136 40%) || loss: 1.8755 || accuracy: 57.009% || Song ID: 45
# 11m 10s (170 50%) || loss: 1.3303 || accuracy: 73.438% || Song ID: 60
# 11m 14s (204 60%) || loss: 2.2721 || accuracy: 38.095% || Song ID: 80
# 11m 18s (238 70%) || loss: 1.0978 || accuracy: 72.826% || Song ID: 124
# 11m 21s (272 80%) || loss: 1.7870 || accuracy: 57.944% || Song ID: 19
# 11m 25s (306 90%) || loss: 1.2672 || accuracy: 58.696% || Song ID: 16
# 11m 29s (340 100%) || loss: 1.9580 || accuracy: 45.556% || Song ID: 333
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GGBd:|"C"edcBcB||"C"c2ee2d"c#"e|:"G"defagfg|"G"gfedcB|:"Am"AGAGBd|"G"g2gg2e||"G"dedBdd:|"G"BddgdB|:"Am"ABAABA:|"G"GAGGBc|"G"dBdgfg|"G"dBdgdd:|"G"BGBdefgfef|"G"g2g
#
# ========= Epoch 20 out of 10000 (0.2 %) =========
#
# 11m 32s (34 10%) || loss: 2.2613 || accuracy: 46.122% || Song ID: 63
# 11m 36s (68 20%) || loss: 1.3249 || accuracy: 59.804% || Song ID: 18
# 11m 40s (102 30%) || loss: 2.0562 || accuracy: 47.253% || Song ID: 276
# 11m 44s (136 40%) || loss: 1.3528 || accuracy: 60.748% || Song ID: 56
# 11m 47s (170 50%) || loss: 1.3280 || accuracy: 68.687% || Song ID: 21
# 11m 51s (204 60%) || loss: 1.3044 || accuracy: 66.355% || Song ID: 191
# 11m 55s (238 70%) || loss: 1.7357 || accuracy: 55.396% || Song ID: 324
# 11m 58s (272 80%) || loss: 1.8411 || accuracy: 54.737% || Song ID: 107
# 12m 2s (306 90%) || loss: 1.7692 || accuracy: 55.769% || Song ID: 306
# 12m 5s (340 100%) || loss: 1.9454 || accuracy: 50.276% || Song ID: 240
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2c"D7"dedc|"G"B2BBcB|"D7"ABAAFD|"G"GBGGBdB|"C"ced"G"BdB|"C"cdc"D"d2B|:"G"GAGFED:|[2"G"G3G2:|c/2B/2c/2|"G"dBdgdd:|"G"gaggge|"G"def"G"gfg|"G"gag"D"agf|"C"edB"D7"def||"G"gbbbag||"D"aga
#
# ========= Epoch 21 out of 10000 (0.21 %) =========
#
# 12m 9s (34 10%) || loss: 1.7650 || accuracy: 51.136% || Song ID: 101
# 12m 13s (68 20%) || loss: 1.4763 || accuracy: 65.315% || Song ID: 8
# 12m 16s (102 30%) || loss: 1.8351 || accuracy: 57.944% || Song ID: 43
# 12m 20s (136 40%) || loss: 2.2301 || accuracy: 43.333% || Song ID: 182
# 12m 23s (170 50%) || loss: 1.6901 || accuracy: 56.311% || Song ID: 62
# 12m 27s (204 60%) || loss: 1.1281 || accuracy: 68.750% || Song ID: 199
# 12m 30s (238 70%) || loss: 1.0993 || accuracy: 70.536% || Song ID: 64
# 12m 34s (272 80%) || loss: 0.8318 || accuracy: 81.720% || Song ID: 135
# 12m 37s (306 90%) || loss: 2.4047 || accuracy: 36.398% || Song ID: 223
# 12m 41s (340 100%) || loss: 1.4575 || accuracy: 68.421% || Song ID: 20
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GGFGA|"G"B2GG2:||:A|:"G"BGEDFA|"G"B2GGAB|"C"cBAABd|"C"ecegfg|"G"dBdgdd:|"C"f2g|:"G"dBGEFG|"G"BABdcd|"G"gfgdcd|"G"gbagfe||"G"dBGG2B|:e|"G"dBGG2B|:"G"dedBAG|"G"G
#
# ========= Epoch 22 out of 10000 (0.22 %) =========
#
# 12m 44s (34 10%) || loss: 1.8510 || accuracy: 52.083% || Song ID: 183
# 12m 48s (68 20%) || loss: 1.3951 || accuracy: 65.421% || Song ID: 314
# 12m 52s (102 30%) || loss: 0.9127 || accuracy: 80.808% || Song ID: 289
# 12m 55s (136 40%) || loss: 2.0529 || accuracy: 48.913% || Song ID: 309
# 12m 59s (170 50%) || loss: 1.3631 || accuracy: 65.263% || Song ID: 107
# 13m 3s (204 60%) || loss: 1.4843 || accuracy: 58.696% || Song ID: 233
# 13m 7s (238 70%) || loss: 1.2569 || accuracy: 64.423% || Song ID: 105
# 13m 10s (272 80%) || loss: 1.4112 || accuracy: 58.333% || Song ID: 310
# 13m 14s (306 90%) || loss: 1.7203 || accuracy: 60.667% || Song ID: 109
# 13m 18s (340 100%) || loss: 1.4362 || accuracy: 63.636% || Song ID: 286
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2dd2B|"C"cdc"G"BAB||"D7"AGEE2D:||:E|"G"GBBBAG|"G"BGGG2||B/2A/2A/2A/2B/2c/2B/2f/2g/2f/2e/2d/2|A/2A/2A/2A/2A/2A/2B/2A/2A/2G/2A/2|AGAGFE^c/2|"D"AGF"G"G2||dBB|:B/2e/2|"G"dBddBG|"C"cedcdB:|[2"A"def"Em"gdB|"D7"c
#
# ========= Epoch 23 out of 10000 (0.22999999999999998 %) =========
#
# 13m 22s (34 10%) || loss: 1.2348 || accuracy: 67.665% || Song ID: 187
# 13m 25s (68 20%) || loss: 1.1598 || accuracy: 71.429% || Song ID: 267
# 13m 29s (102 30%) || loss: 1.1691 || accuracy: 69.231% || Song ID: 306
# 13m 32s (136 40%) || loss: 2.2600 || accuracy: 45.455% || Song ID: 304
# 13m 36s (170 50%) || loss: 1.6178 || accuracy: 47.887% || Song ID: 150
# 13m 40s (204 60%) || loss: 1.4504 || accuracy: 65.789% || Song ID: 92
# 13m 43s (238 70%) || loss: 2.0277 || accuracy: 50.000% || Song ID: 296
# 13m 47s (272 80%) || loss: 0.8798 || accuracy: 78.846% || Song ID: 306
# 13m 51s (306 90%) || loss: 1.7050 || accuracy: 57.554% || Song ID: 324
# 13m 54s (340 100%) || loss: 1.4523 || accuracy: 57.798% || Song ID: 177
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2B"D7"ABA|"G"B2GGAB|"D7"AGA"Em"BGE:|[2"D7"A2AA2B|"Am"cBc"D7"ABc:|de|"G"d2BGBc||"G"dBG"D7"ABA:|"G"G3G2:|B/2A/2|"G"deggdd|"G"gbb"B7"aef|"G"bbgedc:|[2"Em"edB"Am"A3|"G"g2ggfe||"G"deddeg|"Em"efgg2e|"G/d"d
#
# ========= Epoch 24 out of 10000 (0.24 %) =========
#
# 13m 58s (34 10%) || loss: 1.5669 || accuracy: 54.375% || Song ID: 25
# 14m 2s (68 20%) || loss: 1.5852 || accuracy: 54.717% || Song ID: 70
# 14m 5s (102 30%) || loss: 1.4262 || accuracy: 66.667% || Song ID: 179
# 14m 9s (136 40%) || loss: 1.8009 || accuracy: 57.292% || Song ID: 183
# 14m 13s (170 50%) || loss: 1.7527 || accuracy: 59.836% || Song ID: 188
# 14m 16s (204 60%) || loss: 1.4501 || accuracy: 61.111% || Song ID: 181
# 14m 19s (238 70%) || loss: 1.9931 || accuracy: 48.387% || Song ID: 242
# 14m 23s (272 80%) || loss: 0.9414 || accuracy: 73.786% || Song ID: 114
# 14m 27s (306 90%) || loss: 0.6485 || accuracy: 84.946% || Song ID: 136
# 14m 31s (340 100%) || loss: 1.4405 || accuracy: 59.783% || Song ID: 233
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cdBG|"G"G3G3||Bcde|"G"dedBdB||"G"BGBdBG|"C"cededc|"G"BGBdBd|"C"efg"G"def||"G"dBGG2B|"C"cdeedcB||"D7"AGA"Em"BAB||"D"ABAABA|"Em"Bcd"A7"edB|"Em"BcB"D7"cBc|"G"BdBG2:|d||"C"efe
#
# ========= Epoch 25 out of 10000 (0.25 %) =========
#
# 14m 35s (34 10%) || loss: 0.9321 || accuracy: 75.000% || Song ID: 285
# 14m 38s (68 20%) || loss: 1.5957 || accuracy: 61.579% || Song ID: 325
# 14m 41s (102 30%) || loss: 1.7708 || accuracy: 54.167% || Song ID: 183
# 14m 45s (136 40%) || loss: 1.0297 || accuracy: 69.333% || Song ID: 261
# 14m 48s (170 50%) || loss: 1.4964 || accuracy: 58.929% || Song ID: 41
# 14m 52s (204 60%) || loss: 2.2771 || accuracy: 45.833% || Song ID: 2
# 14m 56s (238 70%) || loss: 2.0316 || accuracy: 48.295% || Song ID: 246
# 14m 59s (272 80%) || loss: 0.4586 || accuracy: 91.398% || Song ID: 134
# 15m 3s (306 90%) || loss: 1.4647 || accuracy: 61.250% || Song ID: 25
# 15m 6s (340 100%) || loss: 1.2555 || accuracy: 62.500% || Song ID: 141
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2G"D7"ABc|"G"d2dd2Bc|:Bc||"G"d2BBAG|"C"E2EE2F||"Em"G2ABcB|"D7"ABAFFA|"G"B2B"D"A2B|"D7"AFFDEF|"G"G3D2D||"C"E2D"D7"G2G|"G"BGBdBd|"C"edeG2G|"D7"A3"G"G3:||:"G"g3"D"f3||"C"e3c3||"D7"d^cAA^GG|"G"G2GG2B|"G"d2dd^cd|
#
# ========= Epoch 26 out of 10000 (0.26 %) =========
#
# 15m 10s (34 10%) || loss: 1.3489 || accuracy: 61.446% || Song ID: 132
# 15m 13s (68 20%) || loss: 1.6697 || accuracy: 60.920% || Song ID: 42
# 15m 17s (102 30%) || loss: 1.6167 || accuracy: 50.000% || Song ID: 271
# 15m 21s (136 40%) || loss: 1.7369 || accuracy: 58.779% || Song ID: 221
# 15m 24s (170 50%) || loss: 1.1845 || accuracy: 68.235% || Song ID: 72
# 15m 28s (204 60%) || loss: 0.9564 || accuracy: 72.477% || Song ID: 299
# 15m 31s (238 70%) || loss: 1.5995 || accuracy: 57.068% || Song ID: 298
# 15m 35s (272 80%) || loss: 1.6855 || accuracy: 51.648% || Song ID: 211
# 15m 38s (306 90%) || loss: 1.0171 || accuracy: 66.667% || Song ID: 294
# 15m 43s (340 100%) || loss: 0.8691 || accuracy: 74.038% || Song ID: 284
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cded|"G"BGGGAG||"D"AFDABA|"G"BGBdBG|"D7"FEDG2:||:A|"G"dBdgfe|"G"dBGGBB:|d|"C"efg"D7"f2d/2g/2|"Em"edB"D"AFD|"G"GFBdBB|"Am"ABA"Em"BGD|"G"BGBdBG:|"G"BdBBAB|"D"ABcdcd|"Em"e
#
# ========= Epoch 27 out of 10000 (0.27 %) =========
#
# 15m 46s (34 10%) || loss: 1.3014 || accuracy: 68.966% || Song ID: 197
# 15m 50s (68 20%) || loss: 1.3763 || accuracy: 63.889% || Song ID: 259
# 15m 53s (102 30%) || loss: 1.6048 || accuracy: 58.152% || Song ID: 58
# 15m 57s (136 40%) || loss: 1.2163 || accuracy: 68.571% || Song ID: 239
# 16m 0s (170 50%) || loss: 1.2548 || accuracy: 66.279% || Song ID: 205
# 16m 4s (204 60%) || loss: 0.9126 || accuracy: 75.000% || Song ID: 294
# 16m 7s (238 70%) || loss: 1.0937 || accuracy: 66.304% || Song ID: 23
# 16m 11s (272 80%) || loss: 1.0547 || accuracy: 71.074% || Song ID: 308
# 16m 15s (306 90%) || loss: 1.1640 || accuracy: 61.538% || Song ID: 178
# 16m 18s (340 100%) || loss: 1.8586 || accuracy: 57.233% || Song ID: 203
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GG2F||"G"GBB"D7"AGA|"G"G3G2:|d|"G"g2ggfe|"G"d2BGFE||"D"A2GG2A||"G"BGBBcd|"C"efg"D7"f2g||"D7"fedd^cd|:"G"BdddBG|"C"ced"D7"e2e||"G"deBBAB|"D7"AGA"G"G2:|da/2e/2f/2|"G"gfbbag|"D7"fef"G"g2d|"G"BGGG
#
# ========= Epoch 28 out of 10000 (0.27999999999999997 %) =========
#
# 16m 22s (34 10%) || loss: 2.5169 || accuracy: 45.703% || Song ID: 129
# 16m 26s (68 20%) || loss: 1.0710 || accuracy: 71.875% || Song ID: 119
# 16m 29s (102 30%) || loss: 0.9273 || accuracy: 77.273% || Song ID: 320
# 16m 33s (136 40%) || loss: 0.7514 || accuracy: 79.592% || Song ID: 52
# 16m 37s (170 50%) || loss: 1.1419 || accuracy: 74.257% || Song ID: 34
# 16m 40s (204 60%) || loss: 1.3154 || accuracy: 65.263% || Song ID: 312
# 16m 44s (238 70%) || loss: 1.6428 || accuracy: 60.432% || Song ID: 17
# 16m 47s (272 80%) || loss: 1.2081 || accuracy: 69.231% || Song ID: 306
# 16m 51s (306 90%) || loss: 1.2957 || accuracy: 62.805% || Song ID: 49
# 16m 54s (340 100%) || loss: 1.2354 || accuracy: 70.922% || Song ID: 335
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GG2:|d|:"G"d2dd2d|"C"cegedcB|"C"cdc"G"BAG|"D7"FDDGAG|"G"BAGG2:||:A|"G"BABd2d|"G"dBG"D7"ABA|"G"G3GBc|:dfe/2d/2|"G"g2dBAB|:"G"g2ggfg||"D7"fgaafe|"G"d^cddBd|"G"gbbagd|"C"cee"G"d
#
# ========= Epoch 29 out of 10000 (0.29 %) =========
#
# 16m 58s (34 10%) || loss: 0.9853 || accuracy: 74.324% || Song ID: 241
# 17m 1s (68 20%) || loss: 0.6942 || accuracy: 83.333% || Song ID: 332
# 17m 5s (102 30%) || loss: 1.9395 || accuracy: 45.503% || Song ID: 331
# 17m 8s (136 40%) || loss: 1.7032 || accuracy: 52.060% || Song ID: 6
# 17m 12s (170 50%) || loss: 0.8898 || accuracy: 73.196% || Song ID: 237
# 17m 15s (204 60%) || loss: 1.4197 || accuracy: 57.343% || Song ID: 39
# 17m 19s (238 70%) || loss: 1.1394 || accuracy: 64.444% || Song ID: 200
# 17m 22s (272 80%) || loss: 1.5180 || accuracy: 53.503% || Song ID: 106
# 17m 26s (306 90%) || loss: 1.9546 || accuracy: 51.220% || Song ID: 217
# 17m 30s (340 100%) || loss: 1.1476 || accuracy: 68.794% || Song ID: 335
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GBcB|"C"c2ee2dcBB|"G"G2BBcB|"D7"AGA"Em"BAG|"G"dBB"D7"ABc|:"G"B2d"D7"AGF|"G"G3G2:|B/2f/2|"G"g2GBAB|"D7"AGF"G"G2||"G"DGAGAGB|:dBB|:"D"ABAF2A|:"G"B2BBcd|"G"g2ggab||"C"g2edBG|"Am"Acc"D"d2:||:B/2c/2
#
# ========= Epoch 30 out of 10000 (0.3 %) =========
#
# 17m 33s (34 10%) || loss: 1.2421 || accuracy: 64.035% || Song ID: 165
# 17m 37s (68 20%) || loss: 1.7417 || accuracy: 55.172% || Song ID: 126
# 17m 40s (102 30%) || loss: 0.6190 || accuracy: 82.558% || Song ID: 76
# 17m 44s (136 40%) || loss: 1.8091 || accuracy: 53.261% || Song ID: 50
# 17m 47s (170 50%) || loss: 1.7431 || accuracy: 55.660% || Song ID: 317
# 17m 50s (204 60%) || loss: 1.3822 || accuracy: 61.806% || Song ID: 269
# 17m 54s (238 70%) || loss: 0.9652 || accuracy: 75.248% || Song ID: 264
# 17m 57s (272 80%) || loss: 1.1769 || accuracy: 62.766% || Song ID: 113
# 18m 1s (306 90%) || loss: 2.0311 || accuracy: 52.229% || Song ID: 22
# 18m 5s (340 100%) || loss: 1.8938 || accuracy: 51.042% || Song ID: 2
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|B2cB2c|"G"dedBdg|"D7"fgaagf||"C"ege"G""b"d2d|"C"efedBG|"C"cee"G"dBG|"C"cdc"G"BAG|"D7"FAAGEF|"G"GAB"D"AGF|"Em"EGGB2A|"G"GAB"A7"ABd|"G"gaggdd:|"G"gfbagfe||"D"fafdfa||"C"ggeece
#
# ========= Epoch 31 out of 10000 (0.31 %) =========
#
# 18m 9s (34 10%) || loss: 0.9856 || accuracy: 74.118% || Song ID: 59
# 18m 13s (68 20%) || loss: 1.6362 || accuracy: 58.696% || Song ID: 58
# 18m 16s (102 30%) || loss: 1.4460 || accuracy: 61.006% || Song ID: 203
# 18m 20s (136 40%) || loss: 0.8936 || accuracy: 75.556% || Song ID: 229
# 18m 23s (170 50%) || loss: 0.7901 || accuracy: 72.152% || Song ID: 215
# 18m 27s (204 60%) || loss: 0.8542 || accuracy: 81.343% || Song ID: 115
# 18m 31s (238 70%) || loss: 0.9220 || accuracy: 72.917% || Song ID: 207
# 18m 35s (272 80%) || loss: 1.2151 || accuracy: 68.085% || Song ID: 321
# 18m 39s (306 90%) || loss: 1.5873 || accuracy: 60.294% || Song ID: 147
# 18m 42s (340 100%) || loss: 0.7875 || accuracy: 74.359% || Song ID: 30
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"BGBdcB||"D"AGAdef||"C"ede"G"dcB||"D7"ABG"D7"FGFE|:"G"DGBdBG|"G"deBded|"G"Bdddef|"G"gag"D"fefgfe=c|"G"dBG"C"ABA:|[2"G"G3G2||dBBBcB||"D"ABc"D"dcd|"G"eBADDF|"G"G3"C"g2e||"G"dedd
#
# ========= Epoch 32 out of 10000 (0.32 %) =========
#
# 18m 45s (34 10%) || loss: 0.7562 || accuracy: 77.570% || Song ID: 56
# 18m 49s (68 20%) || loss: 1.4501 || accuracy: 66.393% || Song ID: 188
# 18m 52s (102 30%) || loss: 0.9671 || accuracy: 73.196% || Song ID: 257
# 18m 56s (136 40%) || loss: 1.1438 || accuracy: 72.973% || Song ID: 12
# 18m 59s (170 50%) || loss: 0.9027 || accuracy: 76.699% || Song ID: 53
# 19m 3s (204 60%) || loss: 1.5918 || accuracy: 55.660% || Song ID: 317
# 19m 6s (238 70%) || loss: 1.4807 || accuracy: 60.622% || Song ID: 65
# 19m 10s (272 80%) || loss: 0.9155 || accuracy: 77.011% || Song ID: 137
# 19m 13s (306 90%) || loss: 0.5098 || accuracy: 92.000% || Song ID: 261
# 19m 17s (340 100%) || loss: 1.9625 || accuracy: 51.274% || Song ID: 111
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"BABBAB|"C"cde"G"dBG:|"Am"Aee"G"dBA|"Em"GEGG2:||:A|"G"BAGGFE:|[2"A7"GEA"A7"d2A|"G"B2dBAB|"C"cee"G"dBG|"C"ABc"G/b"BAB|"C"cde"D7"d2A:|"Am"BAcecA|"G"BAGGFG:|[2"A7"ABAGFE||"D"DFA"G"B2A|"Em"BAEG
#
# ========= Epoch 33 out of 10000 (0.33 %) =========
#
# 19m 21s (34 10%) || loss: 1.3855 || accuracy: 62.205% || Song ID: 161
# 19m 25s (68 20%) || loss: 0.9421 || accuracy: 75.248% || Song ID: 264
# 19m 28s (102 30%) || loss: 0.9766 || accuracy: 71.818% || Song ID: 320
# 19m 32s (136 40%) || loss: 1.1708 || accuracy: 67.961% || Song ID: 330
# 19m 35s (170 50%) || loss: 1.3730 || accuracy: 64.804% || Song ID: 61
# 19m 38s (204 60%) || loss: 1.4369 || accuracy: 60.000% || Song ID: 10
# 19m 42s (238 70%) || loss: 0.4676 || accuracy: 83.871% || Song ID: 135
# 19m 45s (272 80%) || loss: 1.0686 || accuracy: 72.581% || Song ID: 100
# 19m 49s (306 90%) || loss: 1.1809 || accuracy: 66.667% || Song ID: 303
# 19m 53s (340 100%) || loss: 0.9618 || accuracy: 73.626% || Song ID: 274
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"BAGDEF:|[2"G"B3B2d|"G"g2ggag||"D"fedcBc|"G"dBGGBG|"D7"FGc"D"Adf||"G"gab"D"afd|"G"BAGFGA|"G"BAG"C"AGE|"G"DGGGAG:|"C"efaag"d#"f|"Em"geeedd|"C"efeedB:|"D7"d3/2e/2dfefe/2e/2f/2g/2d/2|"G"g
#
# ========= Epoch 34 out of 10000 (0.33999999999999997 %) =========
#
# 19m 57s (34 10%) || loss: 1.0686 || accuracy: 69.231% || Song ID: 178
# 20m 0s (68 20%) || loss: 1.0046 || accuracy: 72.932% || Song ID: 329
# 20m 4s (102 30%) || loss: 1.1079 || accuracy: 72.500% || Song ID: 25
# 20m 7s (136 40%) || loss: 1.1324 || accuracy: 70.192% || Song ID: 29
# 20m 11s (170 50%) || loss: 1.0727 || accuracy: 71.569% || Song ID: 167
# 20m 14s (204 60%) || loss: 0.7424 || accuracy: 73.958% || Song ID: 222
# 20m 18s (238 70%) || loss: 1.4616 || accuracy: 58.896% || Song ID: 120
# 20m 21s (272 80%) || loss: 0.9789 || accuracy: 74.227% || Song ID: 257
# 20m 25s (306 90%) || loss: 0.9691 || accuracy: 77.500% || Song ID: 210
# 20m 29s (340 100%) || loss: 2.0852 || accuracy: 48.485% || Song ID: 176
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"BAGG2" ""gb"e|"G"dBG"D"GGF|"G"GBAG2B|:"G"Bdddef||"C"geegfe||"G"deg"Am"a2d||"Am"ecA"G"deg|"G"dcddBG|"C"cec"G"Bcd|"Em"ecA"A7"B2A|"G"BAGBdB|"G"Bddgdd|"C"efe"D7"agf|"G"gbb"A7"bbb|"C"c'ge"D"ddB|
#
# ========= Epoch 35 out of 10000 (0.35000000000000003 %) =========
#
# 20m 32s (34 10%) || loss: 0.9311 || accuracy: 70.297% || Song ID: 232
# 20m 36s (68 20%) || loss: 0.8702 || accuracy: 78.182% || Song ID: 55
# 20m 40s (102 30%) || loss: 0.9536 || accuracy: 72.549% || Song ID: 167
# 20m 43s (136 40%) || loss: 1.1482 || accuracy: 63.253% || Song ID: 275
# 20m 47s (170 50%) || loss: 1.3946 || accuracy: 63.014% || Song ID: 251
# 20m 51s (204 60%) || loss: 0.4343 || accuracy: 87.778% || Song ID: 265
# 20m 55s (238 70%) || loss: 1.0310 || accuracy: 75.000% || Song ID: 225
# 20m 58s (272 80%) || loss: 0.5332 || accuracy: 85.714% || Song ID: 337
# 21m 1s (306 90%) || loss: 1.1179 || accuracy: 68.333% || Song ID: 277
# 21m 5s (340 100%) || loss: 0.7537 || accuracy: 75.789% || Song ID: 151
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GGAG||"D"FGAFDD:||:cBA|"G"G2G"D7"G2A|"G"BddgdB||"D"ABAAdf||"D7"fefdBA||"Em"BAG"D"FGA||"G"Bcd"D"AFAc|"G"BcB"D7"ABA|"G"G2B"D7"ded|"C"cBc"D7"ded||"G"BddGBd||"G"gfg"G"ded|"Am"cAA"Em"BAF|"D7"A2
#
# ========= Epoch 36 out of 10000 (0.36 %) =========
#
# 21m 9s (34 10%) || loss: 1.3090 || accuracy: 67.424% || Song ID: 304
# 21m 12s (68 20%) || loss: 0.9695 || accuracy: 79.310% || Song ID: 197
# 21m 16s (102 30%) || loss: 0.6792 || accuracy: 81.915% || Song ID: 228
# 21m 20s (136 40%) || loss: 1.2932 || accuracy: 64.151% || Song ID: 88
# 21m 23s (170 50%) || loss: 1.0216 || accuracy: 64.762% || Song ID: 122
# 21m 27s (204 60%) || loss: 1.1826 || accuracy: 67.045% || Song ID: 192
# 21m 30s (238 70%) || loss: 1.2695 || accuracy: 69.748% || Song ID: 263
# 21m 34s (272 80%) || loss: 1.3110 || accuracy: 62.264% || Song ID: 88
# 21m 37s (306 90%) || loss: 0.8337 || accuracy: 72.277% || Song ID: 98
# 21m 41s (340 100%) || loss: 1.0615 || accuracy: 70.370% || Song ID: 181
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GBABc|"G"d2BBAB||"G"d^cdefe:|"C"eee"D7"d2d|:"C"e2c"G"d2B|"C"c2ee2d"c#"e|"Em"g2gg2f|"C"edc"D7"dcB||"D7"A3"G"G3:|c/2d|"G"dedBAG|"C"cde"D7"d2e|"G"ded"D7"cBA|"G"GBdg2||efefe/2d|"Em"efggdB||"Em"eBegbad'
#
# ========= Epoch 37 out of 10000 (0.37 %) =========
#
# 21m 44s (34 10%) || loss: 1.0087 || accuracy: 69.748% || Song ID: 33
# 21m 48s (68 20%) || loss: 0.6323 || accuracy: 78.125% || Song ID: 60
# 21m 51s (102 30%) || loss: 1.1335 || accuracy: 68.182% || Song ID: 245
# 21m 55s (136 40%) || loss: 1.0198 || accuracy: 74.490% || Song ID: 5
# 21m 59s (170 50%) || loss: 1.1790 || accuracy: 70.093% || Song ID: 66
# 22m 2s (204 60%) || loss: 1.3726 || accuracy: 65.306% || Song ID: 63
# 22m 6s (238 70%) || loss: 1.2024 || accuracy: 62.500% || Song ID: 29
# 22m 10s (272 80%) || loss: 1.2571 || accuracy: 65.269% || Song ID: 187
# 22m 14s (306 90%) || loss: 0.9820 || accuracy: 68.000% || Song ID: 83
# 22m 17s (340 100%) || loss: 1.2872 || accuracy: 64.550% || Song ID: 331
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"BABdBd|"G"gbg"D7"aad|"C"efg"G"deg|"D7/a"cge"D7"e2d/2c/2|"Em"BAG"D"FED:|"Em"EFEDB,DE|"C"CEFGE=F|"C"E3B,3CB,|:"G"G2BB^AB|"D"A3"G"G3:||:"D"DEFAGF:|[2"A"dB/2c/2|"G"dBBBdB|:"G"BGEDEF|"G"G3GFG||"D"FGF"G"G2:|
#
# ========= Epoch 38 out of 10000 (0.38 %) =========
#
# 22m 21s (34 10%) || loss: 0.7518 || accuracy: 79.412% || Song ID: 68
# 22m 25s (68 20%) || loss: 0.8510 || accuracy: 75.758% || Song ID: 289
# 22m 28s (102 30%) || loss: 1.6463 || accuracy: 54.595% || Song ID: 212
# 22m 32s (136 40%) || loss: 0.7458 || accuracy: 77.885% || Song ID: 105
# 22m 35s (170 50%) || loss: 1.0578 || accuracy: 75.439% || Song ID: 92
# 22m 39s (204 60%) || loss: 1.0165 || accuracy: 71.930% || Song ID: 165
# 22m 43s (238 70%) || loss: 1.1120 || accuracy: 70.115% || Song ID: 87
# 22m 47s (272 80%) || loss: 1.0214 || accuracy: 65.714% || Song ID: 143
# 22m 51s (306 90%) || loss: 0.6926 || accuracy: 78.431% || Song ID: 18
# 22m 54s (340 100%) || loss: 0.9064 || accuracy: 75.000% || Song ID: 99
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"BABdBG|"D7"FGGAGF|"G"GBAGFE||"D7"DFGABc|:"G"dedBAG|"D"ABcAFA||"D"dedcBc|:"G"BGBBAB||"D"AdddBB|:AG||"D"FAFDFA||"D"AFFdBd|d^cdBdB|"G""g"BGDG2:||:df|"G"deBBA
#
# ========= Epoch 39 out of 10000 (0.38999999999999996 %) =========
#
# 22m 58s (34 10%) || loss: 1.2577 || accuracy: 63.333% || Song ID: 80
# 23m 2s (68 20%) || loss: 0.9550 || accuracy: 73.394% || Song ID: 177
# 23m 6s (102 30%) || loss: 0.8249 || accuracy: 75.000% || Song ID: 99
# 23m 10s (136 40%) || loss: 1.0105 || accuracy: 71.918% || Song ID: 251
# 23m 13s (170 50%) || loss: 0.7348 || accuracy: 84.146% || Song ID: 172
# 23m 17s (204 60%) || loss: 0.8805 || accuracy: 71.154% || Song ID: 105
# 23m 20s (238 70%) || loss: 0.6010 || accuracy: 89.286% || Song ID: 93
# 23m 24s (272 80%) || loss: 0.9934 || accuracy: 66.055% || Song ID: 4
# 23m 27s (306 90%) || loss: 0.5632 || accuracy: 86.992% || Song ID: 214
# 23m 31s (340 100%) || loss: 0.9763 || accuracy: 72.340% || Song ID: 335
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GGAB||"C"cedcBd:|"Am"eccec|"D7"AdcABA||"G"B2BBcd|"Am"ecA"G"Bcd||"Am"edAAde||"D"f2ddfa||"C"g^fgecA|"G"Bcd"C"cde|"G7"dBG"D7"AFE:||:"G"DGBdBG||"G"BGGdGG|"G"Bddded|"C"cdc"G"BdB
#
# ========= Epoch 40 out of 10000 (0.4 %) =========
#
# 23m 35s (34 10%) || loss: 0.8100 || accuracy: 79.348% || Song ID: 297
# 23m 38s (68 20%) || loss: 0.8616 || accuracy: 74.528% || Song ID: 164
# 23m 42s (102 30%) || loss: 0.7465 || accuracy: 86.250% || Song ID: 99
# 23m 45s (136 40%) || loss: 1.1791 || accuracy: 70.681% || Song ID: 298
# 23m 49s (170 50%) || loss: 0.7398 || accuracy: 76.923% || Song ID: 30
# 23m 53s (204 60%) || loss: 0.7115 || accuracy: 79.348% || Song ID: 16
# 23m 57s (238 70%) || loss: 1.0863 || accuracy: 69.231% || Song ID: 171
# 24m 0s (272 80%) || loss: 1.3174 || accuracy: 66.842% || Song ID: 325
# 24m 4s (306 90%) || loss: 0.6130 || accuracy: 81.818% || Song ID: 320
# 24m 7s (340 100%) || loss: 0.6106 || accuracy: 81.308% || Song ID: 56
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"Em"G2BBcd|"C"efg"G"dBd:|"Em"g2e"D"a2e|"D7"d2GG2gg/2a/2g/2"C"gfe||"D"faffgaa/2g/2"C"gee|"C"g2fefe|"G"d2BG2G|"C"cdc"G"BABB|"C"cdc"Em"BcB||"C"AcB"D7"AFD:|[2"G"G2EG2B|"G"dedB2g|"C"f2gg2e|"G"dBG"D7"ABAE|:"G"G2B
#
# ========= Epoch 41 out of 10000 (0.41000000000000003 %) =========
#
# 24m 11s (34 10%) || loss: 0.4925 || accuracy: 86.567% || Song ID: 115
# 24m 14s (68 20%) || loss: 0.8662 || accuracy: 71.341% || Song ID: 74
# 24m 18s (102 30%) || loss: 1.5104 || accuracy: 57.143% || Song ID: 208
# 24m 22s (136 40%) || loss: 0.8866 || accuracy: 74.342% || Song ID: 160
# 24m 25s (170 50%) || loss: 0.8477 || accuracy: 76.871% || Song ID: 209
# 24m 28s (204 60%) || loss: 0.5995 || accuracy: 86.170% || Song ID: 305
# 24m 32s (238 70%) || loss: 1.5467 || accuracy: 62.147% || Song ID: 94
# 24m 37s (272 80%) || loss: 1.1492 || accuracy: 66.667% || Song ID: 68
# 24m 40s (306 90%) || loss: 0.8335 || accuracy: 75.229% || Song ID: 234
# 24m 44s (340 100%) || loss: 1.4388 || accuracy: 60.000% || Song ID: 212
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2B"D7"cdc|"G"B2GGBG|"G"d^cd"D7"=cAF|"G"G3G2||B/2d/2|"G"g2gdBG:|d|"C"edegfg|"G"ded"D7"cAA:|e|:"G"defgfg|"C"egg"G/b"dgb||"D"agabag|"D7"fgaage||"Em"geggfe=c|"Em"efedcd=c|"G"BGBBAB|"C"c
#
# ========= Epoch 42 out of 10000 (0.42 %) =========
#
# 24m 47s (34 10%) || loss: 0.9255 || accuracy: 79.762% || Song ID: 78
# 24m 51s (68 20%) || loss: 0.8863 || accuracy: 70.548% || Song ID: 26
# 24m 55s (102 30%) || loss: 0.4100 || accuracy: 87.500% || Song ID: 60
# 24m 58s (136 40%) || loss: 0.5942 || accuracy: 85.366% || Song ID: 217
# 25m 2s (170 50%) || loss: 1.1011 || accuracy: 72.642% || Song ID: 88
# 25m 6s (204 60%) || loss: 0.7483 || accuracy: 77.228% || Song ID: 264
# 25m 10s (238 70%) || loss: 0.6734 || accuracy: 83.486% || Song ID: 234
# 25m 14s (272 80%) || loss: 0.9148 || accuracy: 70.192% || Song ID: 105
# 25m 17s (306 90%) || loss: 1.0284 || accuracy: 70.652% || Song ID: 247
# 25m 20s (340 100%) || loss: 1.1163 || accuracy: 64.815% || Song ID: 310
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"Em"BAB"D7"AFD|"G"DEDG2:||:A|"G"dedBAB|:"G"DddBAG|"D"AGF"D7"AFA||"G"B2G"D7"AGA|"G"GBdg2:|B/2d/2|"G"gab"D7"agd|"G"BdBGAB|"Am"Ace"A7"ece|"Em"edeg2a|"Em"bggg2e||"G"dBdgfg|"D7"fefgdB|"C"cec"G"B
#
# ========= Epoch 43 out of 10000 (0.43 %) =========
#
# 25m 24s (34 10%) || loss: 0.5226 || accuracy: 87.059% || Song ID: 59
# 25m 28s (68 20%) || loss: 0.8956 || accuracy: 74.453% || Song ID: 322
# 25m 31s (102 30%) || loss: 1.1672 || accuracy: 65.190% || Song ID: 121
# 25m 34s (136 40%) || loss: 0.6388 || accuracy: 81.522% || Song ID: 233
# 25m 38s (170 50%) || loss: 0.9442 || accuracy: 76.667% || Song ID: 144
# 25m 42s (204 60%) || loss: 0.5881 || accuracy: 83.036% || Song ID: 41
# 25m 45s (238 70%) || loss: 1.0105 || accuracy: 73.228% || Song ID: 161
# 25m 49s (272 80%) || loss: 0.6394 || accuracy: 78.788% || Song ID: 226
# 25m 52s (306 90%) || loss: 0.7280 || accuracy: 77.885% || Song ID: 105
# 25m 56s (340 100%) || loss: 0.7288 || accuracy: 81.373% || Song ID: 104
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"Em"G2BBAB|"C"c2ee2Bc|:"G"B2dB^AB|:"D7"AFDDF=FF3/2c|"G"deggfg||"G"edddBA||"Em"BAG"D"FAA|"G"GBGBdd|"C"edB"D7"BAG|"Am"F2ED3|"D"DFF"C"EEE:|[2"A"dEc"D"ded||"Em"efggfe|"D"dedd2d|"C"cde"G"dcd|
#
# ========= Epoch 44 out of 10000 (0.44 %) =========
#
# 26m 0s (34 10%) || loss: 0.9583 || accuracy: 65.517% || Song ID: 272
# 26m 3s (68 20%) || loss: 1.2135 || accuracy: 68.586% || Song ID: 298
# 26m 7s (102 30%) || loss: 0.7999 || accuracy: 78.641% || Song ID: 330
# 26m 10s (136 40%) || loss: 1.2593 || accuracy: 61.224% || Song ID: 208
# 26m 14s (170 50%) || loss: 0.4788 || accuracy: 86.486% || Song ID: 230
# 26m 17s (204 60%) || loss: 1.6513 || accuracy: 53.061% || Song ID: 63
# 26m 21s (238 70%) || loss: 0.6148 || accuracy: 85.870% || Song ID: 168
# 26m 25s (272 80%) || loss: 0.5212 || accuracy: 88.636% || Song ID: 192
# 26m 29s (306 90%) || loss: 1.0436 || accuracy: 70.556% || Song ID: 333
# 26m 32s (340 100%) || loss: 0.7410 || accuracy: 77.982% || Song ID: 299
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2AGFG|"C"EcdcdcB|"D7"AGF"G"G2||B|"D7"dcegfg|"D7"fedcBc|"G"BGGG2||B|"D7"dcefgf|"G"gag"B7"f3:||:"Em"efggba|"Em"bab"D"afd||"Em"edBABA:|"Em"g3dcA|:"G"Bdggbb|gedgbb|"G"gfe"D7"aga
#
# ========= Epoch 45 out of 10000 (0.44999999999999996 %) =========
#
# 26m 36s (34 10%) || loss: 0.8610 || accuracy: 69.930% || Song ID: 39
# 26m 40s (68 20%) || loss: 1.1081 || accuracy: 65.409% || Song ID: 203
# 26m 44s (102 30%) || loss: 0.7708 || accuracy: 78.082% || Song ID: 75
# 26m 47s (136 40%) || loss: 0.6778 || accuracy: 77.305% || Song ID: 103
# 26m 50s (170 50%) || loss: 0.3685 || accuracy: 88.776% || Song ID: 337
# 26m 54s (204 60%) || loss: 0.8781 || accuracy: 75.521% || Song ID: 36
# 26m 58s (238 70%) || loss: 0.5007 || accuracy: 86.364% || Song ID: 155
# 27m 1s (272 80%) || loss: 0.4847 || accuracy: 91.791% || Song ID: 115
# 27m 5s (306 90%) || loss: 0.6025 || accuracy: 80.189% || Song ID: 317
# 27m 8s (340 100%) || loss: 0.5088 || accuracy: 85.870% || Song ID: 285
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cdBd|"C"eggg2:|gd/2e/2f/2g2|"C"e2ggec||"G"B2cBAG:|e|"G"d2BGAB|"Am"cBc"D7"AcA:|"G"B2cDEA||"Em"G2EG2E||"Am"ABc"D7"def|"G"gbg"B7"f3:|"C"eggg2g||"D7"f2gafd|"G"gab"Em"dgb||"Em"beegbg|"G"gab"D"agf||"Em"e
#
# ========= Epoch 46 out of 10000 (0.45999999999999996 %) =========
#
# 27m 12s (34 10%) || loss: 1.0228 || accuracy: 67.683% || Song ID: 49
# 27m 16s (68 20%) || loss: 0.6070 || accuracy: 82.828% || Song ID: 226
# 27m 19s (102 30%) || loss: 0.8377 || accuracy: 73.077% || Song ID: 284
# 27m 23s (136 40%) || loss: 0.7104 || accuracy: 81.890% || Song ID: 97
# 27m 27s (170 50%) || loss: 0.6868 || accuracy: 78.641% || Song ID: 268
# 27m 30s (204 60%) || loss: 0.9164 || accuracy: 73.563% || Song ID: 126
# 27m 34s (238 70%) || loss: 0.5823 || accuracy: 86.667% || Song ID: 182
# 27m 37s (272 80%) || loss: 0.8892 || accuracy: 75.138% || Song ID: 153
# 27m 41s (306 90%) || loss: 0.7056 || accuracy: 81.034% || Song ID: 288
# 27m 44s (340 100%) || loss: 0.6808 || accuracy: 81.046% || Song ID: 140
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cd^cd|"D"AGA"Em"BGE:||:df|"G"eBc"D"de^g||"Em"g2b"D"afa|"Em"gef"Em"gab|"A7"agecde|d"3"Bgdef"C"g|"G"dBddBd|"C"efeedc|"G"BGGG2:|g/2a/2g/2|gabgee|ddddfd|"C"efba^ga|"Em"gefg2f
#
# ========= Epoch 47 out of 10000 (0.47000000000000003 %) =========
#
# 27m 48s (34 10%) || loss: 0.3185 || accuracy: 92.793% || Song ID: 230
# 27m 51s (68 20%) || loss: 0.8517 || accuracy: 70.588% || Song ID: 280
# 27m 55s (102 30%) || loss: 0.7987 || accuracy: 76.163% || Song ID: 205
# 27m 58s (136 40%) || loss: 0.7536 || accuracy: 70.370% || Song ID: 85
# 28m 2s (170 50%) || loss: 0.9324 || accuracy: 69.730% || Song ID: 212
# 28m 6s (204 60%) || loss: 0.6933 || accuracy: 79.439% || Song ID: 3
# 28m 10s (238 70%) || loss: 0.7842 || accuracy: 78.889% || Song ID: 333
# 28m 14s (272 80%) || loss: 0.8019 || accuracy: 71.818% || Song ID: 170
# 28m 18s (306 90%) || loss: 0.7414 || accuracy: 75.862% || Song ID: 272
# 28m 21s (340 100%) || loss: 0.4659 || accuracy: 87.805% || Song ID: 217
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cdBG|"C"E2F"G"G2:|d|:AB|"D7"c2GF2ED|:"G"G2BB2A||"G"B2B"D7"cAF:|"D"f3"C"g3g2e|"G"dedBdd:|"C"efe"G"dBG"Am"ecA|"G"BGG"C"g2g||"Am"e2e"D7"e2f"C"g|"G"dBBGAG||"D"FGAABA||"G"BcBBcA||"G"Bcd"Em"efe|dgBdBd:|
#
# ========= Epoch 48 out of 10000 (0.48 %) =========
#
# 28m 25s (34 10%) || loss: 0.8558 || accuracy: 74.107% || Song ID: 328
# 28m 29s (68 20%) || loss: 0.8847 || accuracy: 74.342% || Song ID: 281
# 28m 33s (102 30%) || loss: 0.9852 || accuracy: 76.552% || Song ID: 27
# 28m 36s (136 40%) || loss: 1.0621 || accuracy: 68.367% || Song ID: 5
# 28m 39s (170 50%) || loss: 0.7320 || accuracy: 76.042% || Song ID: 222
# 28m 43s (204 60%) || loss: 0.2058 || accuracy: 95.699% || Song ID: 136
# 28m 46s (238 70%) || loss: 0.7428 || accuracy: 78.125% || Song ID: 37
# 28m 50s (272 80%) || loss: 0.4809 || accuracy: 84.444% || Song ID: 198
# 28m 53s (306 90%) || loss: 0.5431 || accuracy: 88.119% || Song ID: 258
# 28m 57s (340 100%) || loss: 0.7768 || accuracy: 79.630% || Song ID: 336
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cdcB||"C"c2e"D7"d2e|"G"ded"D7"e2d|"G"g2g"D7"dB^G|"Am"AcdecA|"G"G3G2||B/2d/2g/2f/2b/2a/2e/2a/2e/2f/2|"G"gagbaa|"G"g3/2a3/2df/2g/2a||"Bb"b2gg|"D7"deed^c=c|"G"B2GG2g|"G"g2g"D7"de^g"C"g|egfefg:|"D7"a2e/2b"C"gec||"D"d3d3||"G"g2g"D7"d
#
# ========= Epoch 49 out of 10000 (0.49 %) =========
#
# 29m 1s (34 10%) || loss: 1.2548 || accuracy: 63.743% || Song ID: 303
# 29m 4s (68 20%) || loss: 0.4361 || accuracy: 90.217% || Song ID: 297
# 29m 8s (102 30%) || loss: 0.5700 || accuracy: 85.294% || Song ID: 167
# 29m 12s (136 40%) || loss: 0.8424 || accuracy: 75.676% || Song ID: 8
# 29m 15s (170 50%) || loss: 0.6805 || accuracy: 83.193% || Song ID: 263
# 29m 19s (204 60%) || loss: 0.5463 || accuracy: 85.556% || Song ID: 229
# 29m 23s (238 70%) || loss: 0.7474 || accuracy: 75.000% || Song ID: 178
# 29m 26s (272 80%) || loss: 0.3346 || accuracy: 91.954% || Song ID: 42
# ...
# 53m 56s (170 50%) || loss: 0.2782 || accuracy: 93.913% || Song ID: 133
# 54m 0s (204 60%) || loss: 0.2808 || accuracy: 90.426% || Song ID: 113
# 54m 3s (238 70%) || loss: 0.0651 || accuracy: 100.000% || Song ID: 76
# 54m 7s (272 80%) || loss: 0.2509 || accuracy: 93.333% || Song ID: 200
# 54m 10s (306 90%) || loss: 0.4619 || accuracy: 84.247% || Song ID: 75
# 54m 14s (340 100%) || loss: 0.2308 || accuracy: 95.690% || Song ID: 287
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2G"D7"c2A|"G"B3/2A/2EF2E|"D"D3D3|"G"G2GG2ga/2g"D"agfe|"G"dBddBG|"C"cedcBc|:"G"de^dgeB||"Am"Aeee3|"C"egecBG|"G"GBdg2:|d|"Em"efeded|"D7"cAA"Em"BGE:|"Em"geee3|"C"efg"G"dzg:|"D7"fddded|:"G"dBG
#
# ========= Epoch 91 out of 10000 (0.91 %) =========
#
# 54m 18s (34 10%) || loss: 0.3848 || accuracy: 90.840% || Song ID: 221
# 54m 21s (68 20%) || loss: 0.4500 || accuracy: 86.022% || Song ID: 242
# 54m 25s (102 30%) || loss: 0.1819 || accuracy: 95.395% || Song ID: 160
# 54m 29s (136 40%) || loss: 0.1146 || accuracy: 96.951% || Song ID: 74
# 54m 32s (170 50%) || loss: 0.2130 || accuracy: 93.913% || Song ID: 133
# 54m 36s (204 60%) || loss: 0.1741 || accuracy: 95.294% || Song ID: 283
# 54m 40s (238 70%) || loss: 0.2293 || accuracy: 92.000% || Song ID: 118
# 54m 43s (272 80%) || loss: 0.2160 || accuracy: 91.743% || Song ID: 24
# 54m 47s (306 90%) || loss: 0.1606 || accuracy: 93.578% || Song ID: 24
# 54m 50s (340 100%) || loss: 0.1759 || accuracy: 93.684% || Song ID: 79
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|B2G"D7"c2D|"G"B2AG2E|D2BB2A||"G"AFEG2c|:"G"dBB"D7"AGF|"G"G3G3||ecAB^A|B2dG3:||:"Bm"B2Bc2e|"G"d2Bd2Bc|"D"d2df2e||"F#7"f2ef2B|"F"c2eefe|"D7"d6g2|"Am"A2Bc2d|"C"e2d"Am"cBA|"C"G2ee3|"G"d2Gd2d:|"G"B3B2B|"C"c2c"D7"Acc
#
# ========= Epoch 92 out of 10000 (0.9199999999999999 %) =========
#
# 54m 54s (34 10%) || loss: 0.3458 || accuracy: 89.474% || Song ID: 281
# 54m 58s (68 20%) || loss: 0.6417 || accuracy: 80.570% || Song ID: 65
# 55m 2s (102 30%) || loss: 0.1998 || accuracy: 93.939% || Song ID: 304
# 55m 6s (136 40%) || loss: 0.4650 || accuracy: 85.816% || Song ID: 103
# 55m 10s (170 50%) || loss: 0.2160 || accuracy: 93.069% || Song ID: 34
# 55m 13s (204 60%) || loss: 0.1459 || accuracy: 95.918% || Song ID: 337
# 55m 17s (238 70%) || loss: 0.2730 || accuracy: 88.298% || Song ID: 228
# 55m 20s (272 80%) || loss: 0.4636 || accuracy: 85.714% || Song ID: 176
# 55m 24s (306 90%) || loss: 0.2449 || accuracy: 93.684% || Song ID: 107
# 55m 27s (340 100%) || loss: 0.2530 || accuracy: 94.175% || Song ID: 53
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"Em"G2AB2^c:|"D"f3g2efg||B^A^cde=cc|"G"B2GG3:||:"G"B2gD|"G"G2DGAc|"G"B/2DGABcd/2A/2|"G"BAGGBdgfe|"G"d2gdgdB|:"G"g2ggdB||"C"G2GG2g|"Am"e2AG2GA|:"Am"E2B|"F"ABAG2B|"A7"A2FA2d|"Em"gfb"D7"a^ga|g2a"Bm"f2
#
# ========= Epoch 93 out of 10000 (0.9299999999999999 %) =========
#
# 55m 32s (34 10%) || loss: 0.4317 || accuracy: 85.156% || Song ID: 129
# 55m 35s (68 20%) || loss: 0.5618 || accuracy: 83.871% || Song ID: 271
# 55m 39s (102 30%) || loss: 0.3217 || accuracy: 87.500% || Song ID: 178
# 55m 42s (136 40%) || loss: 0.3659 || accuracy: 89.091% || Song ID: 320
# 55m 46s (170 50%) || loss: 0.3020 || accuracy: 92.233% || Song ID: 53
# 55m 50s (204 60%) || loss: 0.1293 || accuracy: 95.833% || Song ID: 259
# 55m 53s (238 70%) || loss: 0.2764 || accuracy: 90.323% || Song ID: 100
# 55m 57s (272 80%) || loss: 0.2388 || accuracy: 92.727% || Song ID: 55
# 56m 1s (306 90%) || loss: 0.1518 || accuracy: 95.506% || Song ID: 185
# 56m 4s (340 100%) || loss: 0.5630 || accuracy: 80.488% || Song ID: 295
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"Em"G2G"Bm"FEF|:"G"G3||"A"E2A"E7"^GAG||"G"G2Be2d|"C"e3"G"dedB2c|"D7"AGF"G"G2:||:A|"D7"d2Ad2cc|:"G"d3/2e/2c"G"BdB|"D"cGA"G"G2:|B|"D"AGF"A"EAA||"D"d2ed2c|"G"B3"D7"G2A|"G"B2BBcB|"A7"^c3A2e||efgBcB|:"D7"c2BA|"G"G2GG2g||"G"dBG"D7"AB
#
# ========= Epoch 94 out of 10000 (0.9400000000000001 %) =========
#
# 56m 8s (34 10%) || loss: 0.3131 || accuracy: 90.278% || Song ID: 148
# 56m 11s (68 20%) || loss: 0.2754 || accuracy: 93.151% || Song ID: 251
# 56m 15s (102 30%) || loss: 0.1610 || accuracy: 94.937% || Song ID: 89
# 56m 19s (136 40%) || loss: 0.2676 || accuracy: 93.043% || Song ID: 1
# 56m 22s (170 50%) || loss: 0.1500 || accuracy: 95.556% || Song ID: 202
# 56m 26s (204 60%) || loss: 0.3245 || accuracy: 91.534% || Song ID: 331
# 56m 29s (238 70%) || loss: 0.3913 || accuracy: 90.714% || Song ID: 125
# 56m 33s (272 80%) || loss: 0.3195 || accuracy: 91.195% || Song ID: 203
# 56m 37s (306 90%) || loss: 0.1646 || accuracy: 95.890% || Song ID: 235
# 56m 40s (340 100%) || loss: 0.2611 || accuracy: 92.929% || Song ID: 313
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cdBG:|"C"E2G3|"Am"c2A"D"d2B|"D7"AFFABd|:AB|"G"G3GAe|"G"dgedcd|"C"f2gg2e|"G"deg"Am"a2a|"C"gge"G""b"d2Bc|:"G"d3/2c/2|"G"deg"C"edc|"G"dBg"A7"Acd:|"C"efe"G"dzg|"C"ece"G"dgg:|"C"egec2g|:"G"dBddedBd|"G"g
#
# ========= Epoch 95 out of 10000 (0.95 %) =========
#
# 56m 44s (34 10%) || loss: 0.1984 || accuracy: 96.040% || Song ID: 34
# 56m 47s (68 20%) || loss: 0.1624 || accuracy: 98.131% || Song ID: 66
# 56m 51s (102 30%) || loss: 0.2251 || accuracy: 90.654% || Song ID: 191
# 56m 55s (136 40%) || loss: 0.5779 || accuracy: 82.397% || Song ID: 6
# 56m 58s (170 50%) || loss: 0.4665 || accuracy: 85.625% || Song ID: 244
# 57m 2s (204 60%) || loss: 0.6522 || accuracy: 78.261% || Song ID: 58
# 57m 6s (238 70%) || loss: 0.3871 || accuracy: 86.869% || Song ID: 289
# 57m 9s (272 80%) || loss: 0.0678 || accuracy: 98.837% || Song ID: 76
# 57m 13s (306 90%) || loss: 0.2756 || accuracy: 91.837% || Song ID: 195
# 57m 17s (340 100%) || loss: 0.2496 || accuracy: 94.898% || Song ID: 195
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"Em"G2G"A7"GFE|"F"F2A"C""e"GAG||"D"FDFFED|:"G"B2B"D7"c2A|:"G"BGBBAB|"D7"d2GAGF|"Em"E6|e6|"G"b2g"D"a2g|"D7"fgffed|"Am"cd^cfef|"G"aag"C7"ebgb|"Am"agaagf|"C"efga2ba3|"G"dedB2g|"C"f2ec2A|:"G"G2GG2G|B2B"D7"A2
#
# ========= Epoch 96 out of 10000 (0.96 %) =========
#
# 57m 20s (34 10%) || loss: 0.2877 || accuracy: 92.391% || Song ID: 16
# 57m 24s (68 20%) || loss: 0.2568 || accuracy: 93.878% || Song ID: 184
# 57m 27s (102 30%) || loss: 0.3964 || accuracy: 90.323% || Song ID: 271
# 57m 31s (136 40%) || loss: 0.5519 || accuracy: 78.947% || Song ID: 35
# 57m 34s (170 50%) || loss: 0.1215 || accuracy: 95.506% || Song ID: 185
# 57m 38s (204 60%) || loss: 0.1991 || accuracy: 93.636% || Song ID: 170
# 57m 41s (238 70%) || loss: 0.3215 || accuracy: 90.476% || Song ID: 176
# 57m 45s (272 80%) || loss: 0.5024 || accuracy: 83.152% || Song ID: 50
# 57m 48s (306 90%) || loss: 0.1439 || accuracy: 96.364% || Song ID: 170
# 57m 52s (340 100%) || loss: 0.3507 || accuracy: 85.345% || Song ID: 287
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"Em"G2AB2A:|"G"B3A|"D"ABc"G"dBGEEG2G|"G"BdBGBGB|:"G"d3/2e/2d"D"ded||"G"B3"D7"G2D:|[2"G"G3"C"g2e|"Am"ABG"D7"DEA|"G"G3GFG|"D"A2GGBdg2|"G"deddBG|"C"cef"Em"ea^g||[1"Em"B2GEzG|:"G"degbag|"D7"fedcBc|"G"GBGG2
#
# ========= Epoch 97 out of 10000 (0.97 %) =========
#
# 57m 56s (34 10%) || loss: 0.2801 || accuracy: 91.818% || Song ID: 320
# 58m 0s (68 20%) || loss: 0.2802 || accuracy: 91.724% || Song ID: 272
# 58m 3s (102 30%) || loss: 0.2787 || accuracy: 90.210% || Song ID: 39
# 58m 7s (136 40%) || loss: 0.3824 || accuracy: 86.517% || Song ID: 238
# 58m 11s (170 50%) || loss: 0.6522 || accuracy: 81.250% || Song ID: 129
# 58m 14s (204 60%) || loss: 0.2578 || accuracy: 90.278% || Song ID: 148
# 58m 18s (238 70%) || loss: 0.4101 || accuracy: 88.785% || Song ID: 56
# 58m 21s (272 80%) || loss: 0.2968 || accuracy: 91.892% || Song ID: 54
# 58m 25s (306 90%) || loss: 0.1539 || accuracy: 96.667% || Song ID: 144
# 58m 28s (340 100%) || loss: 0.4386 || accuracy: 87.171% || Song ID: 338
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2B"D7"cAc||"G"Bcd"D7"cAA|"G"BGBBcdg"C"eB^ABAB||"C"c2BA2B|:"G"dBd"C"e2B|:"G"dBG"D7"AFA|"G"G3GFG|"C"c2Be2e||"G/b"d^cGBAB|"G"D3GFG|"G"FEFD3|"C"E2A"D"D2Bc|"C"E3DB,CC|E3E3|DGAB2c||"G"dedBdg|"C"e
#
# ========= Epoch 98 out of 10000 (0.98 %) =========
#
# 58m 32s (34 10%) || loss: 0.4781 || accuracy: 85.714% || Song ID: 340
# 58m 36s (68 20%) || loss: 0.2274 || accuracy: 93.878% || Song ID: 52
# 58m 39s (102 30%) || loss: 0.2766 || accuracy: 91.538% || Song ID: 315
# 58m 43s (136 40%) || loss: 0.1675 || accuracy: 96.907% || Song ID: 82
# 58m 47s (170 50%) || loss: 0.2136 || accuracy: 92.727% || Song ID: 55
# 58m 50s (204 60%) || loss: 0.2205 || accuracy: 97.122% || Song ID: 213
# 58m 54s (238 70%) || loss: 0.3177 || accuracy: 89.933% || Song ID: 316
# 58m 58s (272 80%) || loss: 0.4082 || accuracy: 87.879% || Song ID: 289
# 59m 1s (306 90%) || loss: 0.2122 || accuracy: 95.597% || Song ID: 31
# 59m 5s (340 100%) || loss: 0.2721 || accuracy: 88.542% || Song ID: 207
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2GBcd|"C"e2c"D7"ABA|"G"B3G2:|d|"D7"c2de2c|:"G"B2BB^A^c|:e|"D"d2BA2G|"D"FEDAF"Em"E|"G"GAG"C"g2A|"G"B/2e/2g"D"fgaa/2g/2|"Bm"f3Bgf|"G"g2g"G7"ggb|"C"e2gg2e|"G"degbge|"C"cgc"G"BdB||"Am"Aeee3|"G"gdddBG|"C"e/2c/2
#
# ========= Epoch 99 out of 10000 (0.9900000000000001 %) =========
#
# 59m 9s (34 10%) || loss: 0.2503 || accuracy: 88.393% || Song ID: 328
# 59m 12s (68 20%) || loss: 0.1886 || accuracy: 95.652% || Song ID: 168
# 59m 16s (102 30%) || loss: 0.1575 || accuracy: 96.809% || Song ID: 163
# 59m 20s (136 40%) || loss: 0.3817 || accuracy: 86.408% || Song ID: 69
# 59m 23s (170 50%) || loss: 0.1808 || accuracy: 93.878% || Song ID: 52
# 59m 27s (204 60%) || loss: 0.1706 || accuracy: 94.706% || Song ID: 283
# 59m 30s (238 70%) || loss: 0.2635 || accuracy: 93.137% || Song ID: 206
# 59m 34s (272 80%) || loss: 0.4261 || accuracy: 87.671% || Song ID: 75
# 59m 38s (306 90%) || loss: 0.2072 || accuracy: 94.958% || Song ID: 33
# 59m 41s (340 100%) || loss: 0.4139 || accuracy: 87.500% || Song ID: 199
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2c"D"de^ga/2e/2a/2g/2a/2g/2f/2g/2b"Em"f2"A"a2"Bm"d3|"Am"aedcBA|:"G"DGB"Bm"d2B|"C"cBc"D7"d2c|"G"B2G"D7"ABA|"G"BGBBd|"G"gfg"C"ege"Am"edc"Em"e2B|"C"G2B"D7"d^ce|"G"dBGGAG|"C"cec"G"BddB/2c/2B|"D7"AcedcB||"Am"Ace"D7"d2e|"G"deGd
#
# ========= Epoch 100 out of 10000 (1.0 %) =========
#
# 59m 45s (34 10%) || loss: 0.2290 || accuracy: 93.229% || Song ID: 36
# 59m 49s (68 20%) || loss: 0.4120 || accuracy: 88.542% || Song ID: 123
# 59m 52s (102 30%) || loss: 0.2791 || accuracy: 92.857% || Song ID: 141
# 59m 56s (136 40%) || loss: 0.1371 || accuracy: 96.842% || Song ID: 20
# 59m 59s (170 50%) || loss: 0.2903 || accuracy: 94.118% || Song ID: 220
# 60m 3s (204 60%) || loss: 0.3648 || accuracy: 88.750% || Song ID: 210
# 60m 7s (238 70%) || loss: 0.0525 || accuracy: 98.851% || Song ID: 42
# 60m 10s (272 80%) || loss: 0.2806 || accuracy: 91.964% || Song ID: 328
# 60m 14s (306 90%) || loss: 0.1454 || accuracy: 94.815% || Song ID: 198
# 60m 17s (340 100%) || loss: 0.1653 || accuracy: 95.161% || Song ID: 100
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cdBG|"C"EGB"D7"AGA|"G"B2AGFE|"D7"D3D2d|"C"efg"D"afd|"Em"g3"Bm"d3:|[2"D"fdd"G"Bcd|"Em"ecF"G"G2:|B|:"G"d3Bc|:"G"d3/2e/2d"D"deff/2g/2|"Am"a2a"Bm"dgaa/2g/2||"D"afd|"G"g2ggfg:|B|:"G"BABdBd|"Em"d^cfg2:||:B/2d/2A/2|"C"e2ee2
#
# ========= Epoch 101 out of 10000 (1.01 %) =========
#
# 60m 21s (34 10%) || loss: 0.1515 || accuracy: 96.429% || Song ID: 93
# 60m 25s (68 20%) || loss: 0.3291 || accuracy: 91.228% || Song ID: 48
# 60m 28s (102 30%) || loss: 0.1564 || accuracy: 95.294% || Song ID: 283
# 60m 32s (136 40%) || loss: 0.0710 || accuracy: 97.753% || Song ID: 185
# 60m 36s (170 50%) || loss: 0.1539 || accuracy: 97.479% || Song ID: 33
# 60m 40s (204 60%) || loss: 0.2303 || accuracy: 93.860% || Song ID: 48
# 60m 44s (238 70%) || loss: 0.5417 || accuracy: 86.275% || Song ID: 68
# 60m 47s (272 80%) || loss: 0.1458 || accuracy: 95.413% || Song ID: 73
# 60m 50s (306 90%) || loss: 0.3379 || accuracy: 91.250% || Song ID: 210
# 60m 54s (340 100%) || loss: 0.2316 || accuracy: 92.929% || Song ID: 152
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cdBdg2B|"G"G3"C"g2g||"C"c'2fed^c||[1"D7"d3/2gdB2A|:"G"DEFGBc|"G"d3B3|:d|"C"efg"D7"f2d|:"D7"c2c|"D7"d2GG2Bc|:"G"d3/2e/2ddBB|"D7"c2ed2c|"G"B2GGAB|"C"cBd"D"A2d|"Am"cBc"D7"d2A=FF3/2e|:"G"d3B2c|:d|"G"g2d"D7"cdc|:"G"B2dB^A
#
# ========= Epoch 102 out of 10000 (1.02 %) =========
#
# 60m 58s (34 10%) || loss: 0.3620 || accuracy: 89.209% || Song ID: 307
# 61m 1s (68 20%) || loss: 0.6963 || accuracy: 79.775% || Song ID: 256
# 61m 5s (102 30%) || loss: 0.1588 || accuracy: 95.833% || Song ID: 112
# 61m 9s (136 40%) || loss: 0.1329 || accuracy: 98.039% || Song ID: 206
# 61m 13s (170 50%) || loss: 0.4991 || accuracy: 87.037% || Song ID: 181
# 61m 17s (204 60%) || loss: 0.3682 || accuracy: 85.039% || Song ID: 57
# 61m 20s (238 70%) || loss: 0.3926 || accuracy: 89.610% || Song ID: 176
# 61m 24s (272 80%) || loss: 0.2886 || accuracy: 92.308% || Song ID: 105
# 61m 28s (306 90%) || loss: 0.3755 || accuracy: 86.726% || Song ID: 142
# 61m 31s (340 100%) || loss: 0.2402 || accuracy: 91.228% || Song ID: 48
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"Em"G2ABcd|"Am"e3g2|"Am"a2A"D7"ABc|"G"d3B2d||"C"e2de3|:"G"d3/2e/2dd^cc|:e|"G"d2dd^cB|:"C"E2GAG|"D"FGAFEF|"G"GFDD2d|"G"g2dBde|:"G"dedd^cd|"C"E2Gc2Bc|:"G"d3/2e/2d"D"deff/2e/2d/2^c/2|:G|"D7"def"G"gdB|GAB"D7"ABA
#
# ========= Epoch 103 out of 10000 (1.03 %) =========
#
# 61m 34s (34 10%) || loss: 0.2228 || accuracy: 93.458% || Song ID: 19
# 61m 38s (68 20%) || loss: 0.3539 || accuracy: 87.821% || Song ID: 171
# 61m 42s (102 30%) || loss: 0.4003 || accuracy: 88.274% || Song ID: 110
# 61m 45s (136 40%) || loss: 0.1133 || accuracy: 98.795% || Song ID: 159
# 61m 48s (170 50%) || loss: 0.2848 || accuracy: 90.909% || Song ID: 127
# 61m 52s (204 60%) || loss: 0.2594 || accuracy: 93.860% || Song ID: 92
# 61m 55s (238 70%) || loss: 0.1711 || accuracy: 96.053% || Song ID: 160
# 61m 59s (272 80%) || loss: 0.2363 || accuracy: 89.062% || Song ID: 60
# 62m 3s (306 90%) || loss: 0.3591 || accuracy: 85.333% || Song ID: 261
# 62m 7s (340 100%) || loss: 0.3372 || accuracy: 88.571% || Song ID: 239
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cdedc|"Bm"B2Bc2e||"Cdim""eb"g3gfe|:"G"d2gd^cG|"D7"A3"G"G3||dedBAF|"G"G3G3:|[2"G"B2AGFE|"G"D2BB2A|A3A3|:d|:"G"g2dBdB|"G"GABd2B||"Am"AcAA2E|"Am"E"3"AAA^Gc|"G"BGBdBd|"C"ece"D7"d2|"C"c2Bc2e|"D7"d3dcB|"C"c2
#
# ========= Epoch 104 out of 10000 (1.04 %) =========
#
# 62m 10s (34 10%) || loss: 0.2286 || accuracy: 92.381% || Song ID: 291
# 62m 14s (68 20%) || loss: 0.2506 || accuracy: 92.857% || Song ID: 41
# 62m 17s (102 30%) || loss: 0.1402 || accuracy: 93.506% || Song ID: 323
# 62m 21s (136 40%) || loss: 0.2846 || accuracy: 90.000% || Song ID: 225
# 62m 25s (170 50%) || loss: 0.2766 || accuracy: 92.638% || Song ID: 7
# 62m 28s (204 60%) || loss: 0.2149 || accuracy: 93.976% || Song ID: 159
# 62m 32s (238 70%) || loss: 0.1690 || accuracy: 95.918% || Song ID: 184
# 62m 35s (272 80%) || loss: 0.1315 || accuracy: 97.297% || Song ID: 12
# 62m 39s (306 90%) || loss: 0.3924 || accuracy: 88.542% || Song ID: 2
# 62m 42s (340 100%) || loss: 0.2814 || accuracy: 91.667% || Song ID: 196
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2G"D7"c2A|:"G"B2ADBc|BAGDFG2|"G"d2^cG2B:||:G|"G"BcBBAG|"C"EFG"D7"A2AF|"G"G3Gzz|"C"c2zB3|"G"G2BA2G:||"Am"A3"G"G3:|[2"G"B2AGFE|"G"D3"G"G2GAB|"F"A^GAGAB|"Am"c2AA^GA|"G"B2B"D7"AGA|"G"G3G3|"G"G6:||:"C"e3c3|"G"d^c
#
# ========= Epoch 105 out of 10000 (1.05 %) =========
#
# 62m 46s (34 10%) || loss: 0.1845 || accuracy: 93.671% || Song ID: 215
# 62m 50s (68 20%) || loss: 0.2642 || accuracy: 91.919% || Song ID: 289
# 62m 53s (102 30%) || loss: 0.1406 || accuracy: 94.681% || Song ID: 253
# 62m 57s (136 40%) || loss: 0.1906 || accuracy: 96.907% || Song ID: 82
# 63m 0s (170 50%) || loss: 0.3778 || accuracy: 88.274% || Song ID: 110
# 63m 4s (204 60%) || loss: 0.4176 || accuracy: 88.433% || Song ID: 201
# 63m 7s (238 70%) || loss: 0.1910 || accuracy: 94.643% || Song ID: 340
# 63m 11s (272 80%) || loss: 0.3695 || accuracy: 88.235% || Song ID: 280
# 63m 14s (306 90%) || loss: 0.1293 || accuracy: 97.087% || Song ID: 13
# 63m 18s (340 100%) || loss: 0.2605 || accuracy: 90.000% || Song ID: 320
#
# Generating example :
#
# M:6/8
# K:G
# "G"G2G"D"A2A|"G"B2cde^c|"D"d3dcB|"C"cBc"Am"A3:||:"G"B3B^AB|d2BBGG:|e|"G"d2BGAB|"C"cde"G"d2B|"C"c2e"D7"e2=f"C"g"A"a2gg2de|"C"g2^f"G"g3|"Em"g2ec2g|"Am"a2ag2e|:"G"d3B2c2|:d|"G"g2d"D7"cdg|:"G"g2dB^Ad|"C"e2ggBA|:"G"G3GAB|d2Bc2G|
#
# ========= Epoch 106 out of 10000 (1.06 %) =========

# %% [markdown]
# ## Load model

# %%
epoch = 100
model = LSTMusic(part_vocab_size, k_vocab_size, m_vocab_size)
model.load_state_dict(torch.load(os.path.join(OUTPUT_PATH, 'model-{}.pth'.format(str(epoch))),map_location=torch.device('cpu')))
model.to(device)
model.eval()
# Out:
# LSTMusic(
#   (part_embeddings): Embedding(1104, 512)
#   (k_embeddings): Embedding(11, 8)
#   (m_embeddings): Embedding(2, 8)
#   (lstm): LSTM(528, 256, num_layers=3, dropout=0.2)
#   (dense): Linear(in_features=256, out_features=1104, bias=True)
# )

# %%
song_idx = 321
song = rep.songs[song_idx]
start_part = rep.songs[song_idx].part[0:20]
start_k = rep.songs[song_idx].metadata['K']
start_m = rep.songs[song_idx].metadata['M']
length = 400
abc = generate(model, start_part, start_k, start_m, length, top_k=2)
# Out:
# M:6/8
# K:D
# A|"D"d2d"A"c2A|"G"BdB"D"AGF|"G"G2e"D"F2d|"Em"E2f"A7"ecc|"D"d3d2:||"Em"g2fe3|"A7"ed^c"D"A2a|"D"g2f"A"e3|"A7"e2cB2A|"D"d2ef2a|"G"bag"D"faa|"A7"gag"D"fgfe|"D"f2ff2f"f#"f|"D"f2dfga|"Em"gfge2d|"A7"cdccAF:|[2"A7"Add"D"def|"G"g3eBc|"G"d3/2ba"A7"gfe|"Bm"dcd"E7"ccB:|[2"A"e3"D"d3|:"A"ecAcee|"D"f2gfef|"C"g2ccfg|"D"a2fa2f|"E7"eBcdcB|"F#m"A3AFA|e2dcBA:|[2"Dm"d3dc|d^cffe=c|:"G"Bdd"A7"efb|"D"afddfa|"G"gfd"A7"ece:|gfe|:"D"fga"A"ece|"D"faa"A7/e"gfe||"D/f+"aga"G"bgg|"D"agf"A7"ede||"D"f2g"Bm"aff||"G"gfedBA|"D"defAFF|:"G"GAB"D7"ABA|d2AABA||d2fa2f|:dBA=FF|"Gm"GBd^c2f|"C"gaag^fg|"D""Bm"f^cfAdefg|"D"abaafg|"D7"adddAF:|[2"D"dcd"A"ede|:fg||"D"fdd"A"efgf/2g/2|"D"a2aba^g|"D"abafag||"Bm"fBgfed|"Em"edBd2A|"D"dfAA2fe|:"G"d3/2e/2d"D"dcd|"G"B2d"D/f+"A2B|"D"A3A2Bc|:"G"d2GBAB|:A|"D"F2DF2d|"D"AGFAGF|"A7"ABAFGF:|F/2F/2G/2|:"A7"AEB"A"EAB|"F#m"AB

# %%
start_part = [part_vocab[500]]
print(start_part)
start_k = k_vocab[7]
start_m = m_vocab[0]
length = 400
abc = generate(model, start_part, start_k, start_m, length, top_k=2)
# Out:
# ['"D7"F2']
# M:5/4
# K:Em
# "D7"F2|d2^cdFE|"G"DEFGAcB^A|"Bb"d^cdfFG|"D"FDDFED|FGc"D"DFA|"D7"d2cAFD|"Em"EFG"A7"F2E|"A7"E2A"D"D2F||"Em"G=FE||"D"DEDF2:||:A|:"G"BAGBddB"Em"e2f|:"G"dc^cd2e|egfe2Bc|"G"dge"D7"dBA:|"G"BAAdef|"G"gbg"D"aba|:"G"g2B"A7"A2B|:ABA|"D"D2DF3:|[2"A7"GECD3|:EA/2B/2|AEAABc|:BB=B"A"A|"A"e2cAB^c|:d|"F"cFAdAF:|E|"Am"E"3"AcA2B|:"G"DEFG2D|"Em"GEEBED|"Em"E2FG2E:|[2"Em""Em"GFAB2A||"D"FEF"G"GFED|"Em"E2FG2"E"^G|:"Em"e2e|"G"dBAgbgf|"G"gbg"D"afd:|"C"ceagec|"G"d3/2e/2afgfg|BAffe=c|"G"BAB"A7"ece||"Bm"dBBfff|efeBAB=ce|:e|"A"aedcde|:ef|"C"g2efgfeBBef|"C"e3BcB|:A|"G"BAB"D"def||"Em"e2b"A7"a2A/2G/2|"G"DGGB/2c/2d/2B/2|"G"GAB"D7"AFD|"Em"EEDG2A|"D"FAAFDF|"G"GBdg2a/2e/2f/2g/2|"G"Bgb"Em"ef^g|"C"c'ba"Em"g2f|"Em"g2eefe:|"D7"d3/2a/2g/2"G"gdg"Em/d+"ggf||Bgf|"Em"ede"A7"gfe|"D"dfe"G"dBG:|"Em"g3"Bm"dedc
